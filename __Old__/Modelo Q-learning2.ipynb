# %% [markdown]
# # Aprendizaje por Refuerzo
# ## Sistema de Recomendación con Aprendizaje por Refuerzo Integrando Ratings

# %%
# pip install pyarrow

# %%
# pip install fastparquet

# %%
# librerías necesarias

import pandas as pd
import random
import numpy as np
import csv


# Datos de interacciones de usuarios con películas, 
# la best_movie_id es el id de la película vista en el mismo día con mejor calificación dada por el usuario
data = pd.read_parquet(r"Netflix_Prize_data\netflix_data_sample.parquet")
# vista previa de los datos
data.head()
# Out:
#   movie_id customer_id  rating best_movie_id  best_rating
# 0    14367          10       5          9340            5
# 1      571          10       4          9340            5
# 2     2122          10       4          9340            5
# 3     6972          10       4          9340            5
# 4    15124          10       4          9340            5

# %% [markdown]
# # Ambiente

# %%
class Environment:
    def __init__(self, data, movie_titles):
        # el ambiente tiene en memoria el dataframe con los datos de las interacciones de usuarios
        self.data = data

        # se escoge como punto de partida cualquier contenido movie_id
        self.initial_state = data.sample(1)["movie_id"].iloc[0]
        

        # se inicializa el estado actual con el estado inicial
        self.state = self.initial_state
        # print(f"Initial state: {self.initial_state}")
        
        # strikes controla la terminación del episodio, 1 strikes y el episodio termina
        self.strikes = 0
        # recompensa por defecto si se llega a 1 strike, está fuera (out)
        self.reward_out = -10

        # se guardan los títulos de las películas para poder mostrarlas en el entorno
        self.movie_titles = movie_titles



    def reset_strikes(self):
        """
        Reinicia los strikes a 0
        """
        self.strikes = 0
       
    def is_terminal(self):
        """
        Determina si el episodio ha terminado, si el agente ha llegado a 1 strike
        """
        return self.strikes == 1

    def get_current_state(self):
        """
        Retorna el estado actual (el movie_id actual)

        Returns
        -------
        int
            Identificador de la película actual (movie_id)
        """
        return self.state

    def get_movie_name(self, movie_id):
        """
        Retorna el nombre de la película dado el movie_id

        Parameters
        ----------
        movie_id : int
            Identificador de la película

        Returns
        -------
        str
            Nombre de la película
        """
        return self.movie_titles[self.movie_titles.movie_id == movie_id].title.iloc[0]


    def get_possible_actions(self, state):
        """
        Retorna las acciones posibles dado un estado (movie_id), 
        las acciones serán cambiar a otro contenido dentro de los candidatos, los cuales son el grupo de películas con mejor calificación
        media del usuario que ha calificado la película actual
        """
        # obtener las películas candidatas, puntuación media dadas por los usuarios que vieron el contenido actual
        candidates = data[data.movie_id == state].groupby("best_movie_id")["best_rating"].mean().sort_values(ascending=False)
        # filtro para que solo se escojan las películas con mayor rating dentro del grupo de candidatos
        candidates = candidates[(candidates==candidates.max())].index

        return candidates
    
    def do_action(self, action):
        """
        Realiza una acción en el entorno, cambiar de contenido a recomendar

        Parameters
        ----------
        action : int
            Identificador de la película a recomendar (movie_id)

        Returns
        -------
        float
            Recompensa de realizar la acción
        int
            Nuevo estado (movie_id)
        bool
            True si el episodio ha terminado, False de lo contrario
        """
        
        reward = 0
        done = False

        if self.is_terminal():
            # si es terminal, se asigna la recompensa por defecto y se termina el episodio
            reward = self.reward_out
            done = True
        else:
            # se obtiene la calificación media de los usuarios que vieron el contenido a recomendar
            rating = self.data[self.data.movie_id == action].rating.mean()
            # se escala la recompensa en función de la calificación media
            reward = self.reward_scalation(rating)

            # si el contenido recomendado tiene una calificación media menor a 3, se considera un strike para el agente,
            # de lo contrario se reinician los strikes
            if reward<0:
                self.strikes += 1
            else:
                self.reset_strikes()

        # recordar que la acción es el cambio de contenido, el nuevo estado es el nuevo contenido (id_movie a recomendar)
        self.state = action
        return reward, self.state, done


    def reward_scalation(self, rating):
        """
        Retorna la recompensa escalada en función de la calificación media de la película a recomendar
        """
        # la escala retorna 1 si el rating medio es 5, 0 si es 3 y -1 si es 1
        return (rating-3)/2


    def reset(self):
        """
        Reinicia el entorno, el estado actual se reinicia al estado inicial
        """
        self.state = data.sample(1)["movie_id"].iloc[0]
        # print(f"Initial state: {self.state}")

# %% [markdown]
# # Agente

# %%
class Agent:
    def __init__(self, env, gamma=0.9, alpha=0.1, epsilon=0.9, episodes=1000, qtable=None):

        # el agente tiene en memoria el ambiente
        self.environment = env
        # gamma factor de descuento
        self.gamma = gamma
        # alpha tasa de aprendizaje
        self.alpha = alpha
        # epsilon factor de exploración
        self.epsilon = epsilon
        # decay_rate tasa de decaimiento de epsilon
        self.decay_rate = 0.9

        # número de episodios
        self.episodes = episodes

        # Q-table se puede inicializar con valores ya entrenados del parámetro 'qtable'. 
        # Esto, junto a un valor de exploración pequeño, hará que el agente utilice esta política aprendida con antelación. 
        # Se inicializa como un diccionario vacío en caso de no recibir la política como parámetro, y 
        # los estados y acciones se irán añadiendo a medida que se vayan explorando (esto evita crear una tabla muy grande)
        self.qtable = qtable if qtable is not None else {}


    def run(self):
        """
        Entrenamiento del agente, se ejecutan los episodios hasta la condición de terminación de cada uno y se actualiza la Q table

        Returns
        -------
        dict
            Q table con los valores de los estados y acciones aprendidos
        """


        for episode in range(self.episodes):
            self.environment.reset()
            # estado actual (movie_id actual)
            state = self.environment.get_current_state()
            # done indica si el episodio ha terminado (si el agente ha llegado a 3 strikes)
            done = False

            while not done:
                # se escoge una acción (cambio de contenido) al azar o con base en la Q table determinado por epsilon
                action = self.random_action(state)

                reward, next_state, done = self.step(action)
                
                # si el estado no está en la Q table, se añade
                if state not in self.qtable:
                    self.qtable[state] = {action: 0}
                else:
                    # si la acción no está en la Q table, se añade
                    if action not in self.qtable[state]:
                        self.qtable[state][action] = 0

                # valor del estado actual en la Q table
                old_value = self.qtable[state][action]
                # valor del estado siguiente en la Q table
                next_max = max(self.qtable[next_state].values()) if next_state in self.qtable else 0
                # cálculo del nuevo valor del estado actual con base en la ecuación de Bellman
                new_value = old_value + self.alpha * (reward + self.gamma * next_max - old_value)


                if action is not None:
                    self.qtable[state][action] = new_value
                else:
                    self.qtable[state][action] = reward
                    
                state = next_state
            # decaimiento de epsilon
            self.epsilon = max(self.epsilon * self.decay_rate,0.01)

        return self.qtable


    def random_action(self, current_state):
        """
        Retorna una acción al azar o con base en la Q table determinado por epsilon
        
        Parameters
        ----------
        current_state : int
            Estado actual (movie_id actual)

        Returns
        -------
        int
            Acción a realizar (movie_id a recomendar)
        """

        possible_actions = self.environment.get_possible_actions(current_state)

        # fase de exploración (adquirir conocimiento)
        if random.uniform(0, 1) < self.epsilon:
            return random.choice(possible_actions)
        
        # fase de explotación del conocimiento
        else:
            # si aún no tiene conocimiento del estado actual, se escoge una al azar    
            if ~ (current_state in self.qtable.keys()):
                best_action = random.choice(possible_actions)

            # si ya tiene conocimiento, se escoge la acción con mayor valor
            else:
                max_value = max(self.qtable[current_state].values())
                max_keys = [key for key, value in self.qtable[current_state].items() if value == max_value]
                best_action = random.choice(max_keys)

            return best_action



    
    def step(self, action):       
        """
        Realiza una acción en el entorno, cambiar de contenido a recomendar
        
        Parameters
        ----------
        action : int
            Identificador de la película a recomendar (movie_id)
        
        Returns
        -------
        float
            Recompensa de realizar la acción"""

        return self.environment.do_action(action)
    

    def actions_values(self):
        """
        Retorna las películas recomendadas basándose en el valor más alto de todos los estados explorados
        
        Returns
        -------
        dict
            Diccionario con los estados y las acciones recomendadas
        dict
            Diccionario con los valores de los estados y acciones
        dict
            Diccionario con las películas recomendadas por cada película actual
        """

        actions = {}
        values = {}
        recommended = {}
        for state, action_values in self.qtable.items():
            
            # id de la película recomendada con mayor valor en la Q table por cada estado
            max_action = max(action_values, key=action_values.get)
            actions[state] = max_action
            
            values[state] = max(action_values.values())
            
            # nombre de película actual
            actual_movie = self.environment.get_movie_name(state)
            recommended[actual_movie] = self.environment.get_movie_name(max_action)
        
        return actions, values, recommended

# %% [markdown]
# # Funciones de persistencia de Q-Table

# %%
# Funciones para persistir y cargar los datos de la q-table

import json

def save_qtable(qtable, file_name):
    """
    Guarda la Q table en un archivo JSON

    Parameters
    ----------
    qtable : dict
        Q table con los valores de los estados y acciones aprendidos
    file_name : str
        Nombre del archivo donde se guardará la Q table
        
    """
    try:
        with open(file_name, 'w') as file:
            json.dump(qtable, file, indent=4)
        print(f"Qtable ha sido guardado en {file_name}")
    except IOError as e:
        print(f"An error occurred while saving data to {file_name}: {e}")




def load_qtable(file_name):
    """
    Carga la Q table desde un archivo JSON
    
    Parameters
    ----------
    file_name : str
        Nombre del archivo donde se encuentra la Q table
        
    Returns
    -------
    dict
        Q table con los valores de los estados y acciones aprendidos
    """
    try:
        with open(file_name, 'r') as file:
            data = json.load(file)
        return data
    except IOError as e:
        print(f"An error occurred while reading data from {file_name}: {e}")
        return None
    




# Datos de películas, contiene el id de la película, el año y el título
def read_movie_titles(csv_file_path):
    """
    Lee un archivo CSV con información de películas y retorna un DataFrame con los datos
    
    Parameters
    ----------
    csv_file_path : str
        Ruta del archivo CSV
    
    Returns
    -------
    pd.DataFrame
        DataFrame con los datos de las películas
        
    """

    list_of_movies = []

    # Open the CSV file for reading
    with open(csv_file_path, mode='r', newline='') as file:
        # Read the file line by line
        for line in file:
            # Strip any leading/trailing whitespace including newlines
            line = line.strip()
            
            # Split the line into exactly 3 parts: first three fields and the rest
            parts = line.split(',', 2)
            
            # Ensure that we have exactly 4 parts (the last part may contain commas)
            if len(parts) == 3:
                id_field = parts[0]
                name_field = parts[1]
                description_field = parts[2]
                
                list_of_movies.append((id_field, name_field, description_field))

            else:
                # Handle cases where the line does not contain enough commas
                print(f'Unexpected line format: {line}')

    movie_titles = pd.DataFrame(list_of_movies, columns=["movie_id", "year", "title"])

    return movie_titles

# %% [markdown]
# # Entrenamiento

# %%
# EJECUTAMOS EL AGENTE EN ESCENARIO DE ENTRENAMIENTO

env = Environment(data, read_movie_titles(r"Netflix_Prize_data\movie_titles.csv"))

#creación del agente
agent = Agent(env, gamma=0.9, alpha=0.1, epsilon=0.9, episodes=2000) 

# Ejecución del agente y obtenemos la Q-table con la política encontrada por el agente
qtable = agent.run()

# La política de esta Q-table la guardamos para poder usarla después
save_qtable(qtable, 'qtable.json')

actions, values, recommended = agent.actions_values()
recommended
# Out:
# Qtable ha sido guardado en qtable.json
# {'Family Guy Presents: Stewie Griffin: The Untold Story': 'Reservoir Dogs',
#  'Reservoir Dogs': 'The Party',
#  'The Party': 'Frida',
#  'Much Ado About Nothing': 'Ransom',
#  'Today You Die': 'Taking Lives',
#  'Kissing Jessica Stein': 'Mystic River',
#  'Frantic': 'Lonesome Dove',
#  'Clueless': 'Rudolph the Red-Nosed Reindeer',
#  'Kiss of the Dragon': 'CSI: Season 1',
#  'Spirit: Stallion of the Cimarron': 'Sex and the City: Season 4',
#  'The League of Extraordinary Gentlemen': 'Choke',
#  'The Mummy Returns': 'Nausicaa of the Valley of the Wind',
#  'Blues Brothers 2000': "Bram Stoker's Dracula",
#  'Rookie of the Year': 'Falling Down',
#  'In Good Company': "Aliens: Collector's Edition",
#  'The Lost World: Jurassic Park': "Gone with the Wind: Collector's Edition",
#  'Tomb Raider': 'Santana: Supernatural Live',
#  'I Am Sam': "Murphy's Romance",
#  'Wild Wild West': 'U.S. Marshals',
#  'Young Guns': "Pooh's Heffalump Movie",
#  'The Sound of Music': 'Being John Malkovich',
#  'Raising Arizona': 'The Bridge on the River Kwai',
#  'Thirteen': 'Cleopatra Jones',
#  'A Beautiful Mind': 'The Work of Director Michel Gondry',
#  'Doctor Who: The Five Doctors': 'Moonstruck',
#  'Pitch Black': 'The Gnome-Mobile',
#  'As Good as It Gets': 'The Addams Family',
#  'Die Hard 2: Die Harder': 'Some Kind of Wonderful',
#  'Young Guns II': 'The Wedding Planner',
#  'The Running Man': 'The Phantom of the Opera: Special Edition',
#  'Hannibal': 'Home Movie',
#  'E.T. the Extra-Terrestrial: The 20th Anniversary (Rerelease)': 'Under the Tuscan Sun',
#  'Independence Day': 'A Passage to India',
#  'The Sixth Sense': 'The Pianist',
#  'Sister Act 2: Back in the Habit': 'Bad Boys',
#  'Entrapment': 'Indiana Jones and the Temple of Doom',
#  "Look Who's Talking Now": 'On Golden Pond',
#  'Open Water': 'Invader Zim',
#  'Rocky II': 'Back to the Future',
#  'Shrek 2': 'Raw',
#  "Harrison's Flowers": 'Pirates of the Caribbean: The Curse of the Black Pearl',
#  'How to Lose a Guy in 10 Days': 'City of God',
#  'No Good Deed': 'The Simpsons: Season 3',
#  'The Terminator': 'The Great Santini',
#  'Kindergarten Cop': 'Chris Rock: Bring the Pain',
#  'Beverly Hills Cop': 'Husbands and Wives',
#  'Best in Show': 'Swimming Pool',
#  'King Arthur': 'The Sum of All Fears',
#  'Ice Age': 'Bill Cosby: Himself',
#  'Frequency': 'Back to the Future',
#  'Inventing the Abbotts': 'Buffalo Soldiers',
#  'Harry Potter and the Prisoner of Azkaban': 'The Bedford Incident',
#  'The Net': 'End of Days',
#  'Star Trek III: The Search for Spock': 'Jaws: The Revenge',
#  'The Missing': 'Hidalgo',
#  'Robots': 'Training Day',
#  'Jerry Maguire': 'The Breakfast Club',
#  'Pulp Fiction': 'The Limey',
#  'Waking Ned Devine': 'Toy Story',
#  'Chariots of Fire': 'Scarface',
#  "Dude, Where's My Car?": 'The Lost Boys: Special Edition',
#  "There's Something About Mary: Special Edition": 'Beaches',
#  '28 Days': 'The Twilight Zone: Vol. 17',
#  'Lucky Town': 'Parenthood',
#  'The Lost Weekend': 'Summer of Sam',
#  'Con Air': 'Dragonheart',
#  'The Italian Job': 'One False Move',
#  'Lord of the Rings: The Return of the King: Extended Edition': 'I Love Lucy: Season 2',
#  'The Fifth Element': 'A Very Long Engagement: Bonus Material',
#  'Patch Adams': 'L.A. Confidential',
#  'Ever After: A Cinderella Story': 'If These Walls Could Talk',
#  'The Silence of the Lambs': 'Face/Off',
#  'The Green Mile': 'The Matrix: Reloaded',
#  'Dial M for Murder': 'Mississippi Burning',
#  'Desperate Measures': 'Nosferatu: Original Version',
#  'The Graduate': 'Heat: Special Edition',
#  'City of God': 'Sleepless in Seattle',
#  'The Killing Fields': 'The Hunt for Red October',
#  'Finding Nemo (Widescreen)': 'Viva La Bam: Season 1',
#  'The Fan': 'New Jack City: Special Edition',
#  'Fantasia': "The Wizard of Oz: Collector's Edition",
#  'Clear and Present Danger': 'No Way Out',
#  'She Wore a Yellow Ribbon': 'Out for Justice',
#  'Sex and Lucia': 'Men of Honor',
#  'The Life Aquatic with Steve Zissou': 'Lost in Translation',
#  'Midnight Cowboy': "The Wizard of Oz: Collector's Edition",
#  'Private Benjamin': 'Rob Roy',
#  'Wag the Dog': 'The Postman Always Rings Twice',
#  'Stuart Little': 'Curly Sue',
#  'Morvern Callar': 'Bend It Like Beckham',
#  'A League of Their Own': 'The Professional',
#  'Persuasion': 'Best of The Muppet Show: Steve Martin / Carol Burnett / Gilda Radner',
#  'Being John Malkovich': 'Mission: Impossible II',
#  'Mr. Smith Goes to Washington': 'From Dusk Till Dawn',
#  'Homicide: Life on the Street: Season 5': 'Lord of the Rings: The Two Towers',
#  'Lord of the Rings: The Fellowship of the Ring': 'Firestarter',
#  'Stripes': 'The Ice Storm',
#  'Scary Movie 2': 'John Q',
#  'The Fog': 'Catch Me If You Can',
#  'The Matrix: Reloaded': 'Batman Begins',
#  'George Winston: Seasons in Concert: Windham Hill': 'Heartbreakers',
#  'Crouching Tiger, Hidden Dragon': 'Far from Heaven',
#  'Species II': 'Missing in Action 2: The Beginning / Missing in Action 3: Braddock',
#  'Top Gun': "The Devil's Backbone",
#  'Mad Max': 'The Simpsons: Treehouse of Horror',
#  'Scotland, PA': 'Moulin Rouge',
#  "National Lampoon's Vacation": 'A Clockwork Orange',
#  'Drop Zone': 'House of Sand and Fog',
#  'A Thousand Clouds of Peace': 'Dances With Wolves: Special Edition',
#  'Message in a Bottle': 'Polish Wedding',
#  'Matchstick Men': 'Chicago',
#  'The Waterboy': 'Big Jake',
#  'Billy Elliot': 'Cracker: Series 2',
#  'Kinsey': "Gone with the Wind: Collector's Edition",
#  'Pokemon Heroes: The Movie': 'Fried Green Tomatoes',
#  'Raging Bull': 'Fame',
#  "Elvis: That's the Way It Is": 'The Lemon Drop Kid',
#  'The Notebook': 'Boyz N the Hood',
#  'Futurama: Vol. 3': 'Dangerous Minds',
#  'Ghostbusters': 'Nightbreed',
#  "What's Cooking?": 'The Autobiography of Miss Jane Pittman',
#  'Wire in the Blood: Season 2': 'American Beauty',
#  'Lock Up': 'Urban Cowboy',
#  'The Breakfast Club': 'Sex and the City: Season 4',
#  "The General's Daughter": 'X-Men',
#  "Bill & Ted's Excellent Adventure": 'Like Water for Chocolate',
#  'Red Dragon': 'Kill Bill: Vol. 1',
#  'Equilibrium': 'Dogma',
#  'House of Sand and Fog': 'Runaway Bride',
#  'The Royal Tenenbaums': 'Star Trek: Voyager: Season 1',
#  'Johnny English': 'Cinderella: Special Edition',
#  'The Terminal': 'My Own Private Idaho',
#  'Friends: Season 8': 'The Deer Hunter',
#  'Driving Miss Daisy': 'Star Trek: Voyager: Season 1',
#  'Spider-Man': 'Wings of Desire',
#  'What About Bob?': 'The Santa Clause',
#  'The Transporter': 'Anatomy of a Murder',
#  'A Christmas Carol': "Aliens: Collector's Edition",
#  'Earth Girls Are Easy': 'The Santa Clause',
#  '24: Season 1': 'Smallville: Season 1',
#  'Star Trek: The Next Generation: Season 5': "Monty Python's The Meaning of Life: Special Edition",
#  'Erin Brockovich': "Adam's Rib",
#  'Men in Black II': 'The First Wives Club',
#  'The Mask of Zorro': 'Inu-Yasha',
#  'Meet the Parents': "Breakfast at Tiffany's",
#  'Wallace & Gromit in Three Amazing Adventures': 'The Professional',
#  'Starsky & Hutch': 'Bambi: Platinum Edition',
#  'Under the Tuscan Sun': 'Tightrope',
#  'Profiler: Season 2': 'The Simpsons: Season 1',
#  'X-Men': 'Jack',
#  'Big Fish': 'Cool Hand Luke',
#  'Two Weeks Notice': 'Scarface: 20th Anniversary Edition',
#  'Chisum': 'The Bourne Supremacy',
#  'Hairspray': 'Ghost in the Shell',
#  'The Accused': 'Some Like It Hot',
#  'The Other Sister': 'Ransom',
#  'Paycheck': 'Double Jeopardy',
#  'Wyatt Earp: Special Edition': 'Star Trek: Enterprise: Season 1',
#  'Whale Rider': 'Justice League',
#  'Memphis Belle': 'About a Boy',
#  'Everyone Says I Love You': 'Reservoir Dogs',
#  'Star Wars: Episode VI: Return of the Jedi': 'Passion Fish',
#  'Black Rain': 'Planes, Trains and Automobiles',
#  'Airheads': 'Conan the Barbarian',
#  'Little Big Man': 'The Man Who Knew Too Much',
#  'Memento': 'The Last House on the Left',
#  'Hellraiser VI: Hellseeker': 'The Evil Dead',
#  'Stigmata': 'Saturday Night Live: The Best of Will Ferrell 2',
#  'A Murder of Quality': 'The Wire: Season 2',
#  "You've Got Mail": 'The Women',
#  'Bachelor Party': 'True Stories: Talking Heads',
#  'Malcolm X': "Salem's Lot",
#  'All Quiet on the Western Front': 'The Exorcist: Restored Version',
#  'XXX: State of the Union': 'As Good as It Gets',
#  'Deuce Bigalow: Male Gigolo': 'Two Can Play That Game',
#  'Father of the Bride 2': 'Fight Club',
#  'Grumpier Old Men': 'The Road Warrior',
#  'American Splendor': 'Lilo and Stitch',
#  'Bambi: Platinum Edition': 'Dogma',
#  'Hidalgo': 'Futurama: Monster Robot Maniac Fun Collection',
#  'Something to Talk About': 'Gilmore Girls: Season 1',
#  'Conan the Destroyer': 'Madonna: Music',
#  'Diplomatic Siege': 'Forrest Gump',
#  'Pirates of the Caribbean: The Curse of the Black Pearl': 'Goldfinger',
#  'A Nightmare on Elm Street': 'Life Is Beautiful',
#  'Monkey Shines': 'Scream 3',
#  'The Hustler': 'Hellbound: Hellraiser II',
#  'Twister': 'Do You Believe in Miracles?',
#  'Holes': 'The Usual Suspects',
#  'The Limey': 'Man on Fire',
#  'Antz': 'Out of Africa',
#  'Spaceballs': 'The Sandlot 2',
#  "The Devil's Advocate": "Aliens: Collector's Edition",
#  'Hellboy': 'The Navigator: A Time Travel Adventure',
#  'Planet of the Apes': 'Futurama: Monster Robot Maniac Fun Collection',
#  'So I Married an Axe Murderer': 'The Shield: Season 1',
#  'Rain Man': 'As Time Goes By: Series 1 and 2',
#  'Sister Act': "Wolf's Rain",
#  'Planes, Trains and Automobiles': 'Gunga Din',
#  'Star Trek: First Contact': 'Bedazzled',
#  'Three Men and a Baby': 'Cabaret',
#  'The Hours': 'The Last Emperor',
#  'The Boys and Girl from County Clare': 'Dawn Anna',
#  'Shanghai Noon': 'Spider-Man vs. Doc Ock',
#  'The Basketball Diaries': 'Sex and the City: Season 6: Part 1',
#  'The Patriot': 'Hook',
#  'Ran': 'Buffy the Vampire Slayer: Season 6',
#  "Predator: Collector's Edition": 'Hackers',
#  'Lovely & Amazing': 'The Quiet American',
#  'The First Wives Club': 'Dolores Claiborne',
#  'The Stepford Wives': 'Harold and Maude',
#  'Fahrenheit 9/11': "Chappelle's Show: Season 1",
#  'Monsters, Inc.': 'Cube 2: Hypercube',
#  'Freaky Friday': 'Pieces of April',
#  'Cheaper by the Dozen': 'John Q',
#  'Sherlock Holmes: The Woman in Green': 'The Final Countdown',
#  'No Deposit No Return': 'The Celebration',
#  "Dante's Peak": 'Threesome',
#  'The Changeling': 'Sleepless in Seattle',
#  'Angel Eyes': 'Gone in 60 Seconds',
#  'The Bourne Supremacy': 'Nausicaa of the Valley of the Wind',
#  'The Day After Tomorrow': 'Tipping the Velvet',
#  'Blade': 'Eddie Izzard: Circle',
#  'Forrest Gump': 'Chinatown',
#  'Enemy of the State': "The Devil's Own",
#  "Monty Python's And Now for Something Completely Different": 'The Sopranos: Season 3',
#  'Stepmom': 'Caddyshack',
#  'The Wedding Singer': 'A River Runs Through It',
#  'End of Days': 'High Plains Drifter',
#  'P.S.': 'Clue',
#  'The Bodyguard': 'Lord of the Rings: The Two Towers: Extended Edition',
#  'Mystery, Alaska': 'Saving Private Ryan',
#  'Beverly Hills Cop II': 'Music Box',
#  'Ghost': 'Not Without My Daughter',
#  'Batman Returns': 'Crocodile Dundee in Los Angeles',
#  'Frida': 'Babylon 5: The River of Souls',
#  'Beetlejuice': 'Dark City',
#  'Emma': 'Robin Williams: Live on Broadway',
#  "All the President's Men": 'The Pacifier',
#  'Catch Me If You Can': 'The Twilight Zone: Vol. 15',
#  'Barbershop': "Metallica: Cliff 'Em All",
#  "Mystery Science Theater 3000: The Brain That Wouldn't Die": 'The Sopranos: Season 3',
#  'Starship Troopers': 'Wallace & Gromit in Three Amazing Adventures',
#  'American Beauty': 'A Little Princess',
#  'The Birdcage': 'Nine to Five',
#  'The Life of David Gale': 'Kikujiro',
#  'Body Chemistry': 'In the Mood for Love',
#  'Harold and Kumar Go to White Castle': 'The O.C.: Season 1',
#  'Deep Blue Sea': 'Star Wars: Episode V: The Empire Strikes Back',
#  'National Treasure': 'Wait Until Dark',
#  'Star Wars: Episode IV: A New Hope': 'Mansfield Park',
#  'Monty Python and the Holy Grail': 'Earth vs. The Flying Saucers',
#  'Not Without My Daughter': 'A Little Princess',
#  'Shrek (Full-screen)': 'Gilmore Girls: Season 3',
#  'The Land Before Time': 'The Sandlot',
#  'The Bank Dick': 'North by Northwest',
#  "A Knight's Tale": 'Spitfire Grill',
#  'Far and Away': 'Amadeus',
#  'Bad Lieutenant': 'Clerks',
#  'Blood Work': 'The Man Who Knew Too Little',
#  'Apocalypse Now': 'Rocky IV',
#  'Lethal Weapon 3': 'Say Anything',
#  'Things You Can Tell Just By Looking at Her': 'Girl with a Pearl Earring',
#  'Wizards': 'Trigun',
#  'American Pie 2': 'The Manchurian Candidate',
#  'Armageddon': 'Sixteen Candles',
#  'Angels in the Outfield': 'Thirteen',
#  'Bridget Jones: The Edge of Reason': 'Monsoon Wedding',
#  'The Goonies': 'Woman of the Year',
#  'Training Day': 'Best in Show',
#  'The Mayor of Casterbridge': 'Mansfield Park',
#  'Meet the Fockers': "My Best Friend's Wedding",
#  'Without a Paddle': 'Monk: Season 3',
#  'Road to Perdition': 'The Count of Monte Cristo',
#  'The Pelican Brief': 'Rambo: First Blood Part II',
#  "Ocean's Eleven": 'Bringing Down the House',
#  'Dr. Dolittle': 'Rambo: First Blood Part II',
#  'Liam': 'The Professional',
#  'Missing in Action': 'Lonesome Dove',
#  'Titanic': 'An American Werewolf in Paris',
#  'The Chronicles of Riddick: Dark Fury': 'Aqua Teen Hunger Force: Vol. 1',
#  'Big Trouble in Little China': 'Thunderbirds',
#  "Ferris Bueller's Day Off": 'Lonesome Dove',
#  'Almost Famous': 'Nip/Tuck: Season 2',
#  'Merlin: Special Edition': 'The King and I',
#  'Swordfish': "Cinema Paradiso: Director's Cut",
#  'From Dusk Till Dawn': 'Armageddon',
#  'Sex and the City: Season 6: Part 2': 'Garden State',
#  'Dragnet': 'Dead Man Walking',
#  'Friday the 13th: Part 2': 'Coach Carter',
#  'Rollerball': 'The Bad and the Beautiful',
#  'Metropolis': 'Solaris',
#  'Jurassic Park': 'Mississippi Burning',
#  'An Officer and a Gentleman': 'Coming to America',
#  'The Passion of the Christ': 'Woman Thou Art Loosed',
#  'The Omen': "Sharpe 4: Sharpe's Enemy",
#  'The Day of the Jackal': 'Sling Blade',
#  'Love Actually': 'Risky Business',
#  'The Sopranos: Season 5': 'Friends: Season 2',
#  'Tarzan 2': 'Casper',
#  'Hope Floats': 'Robin Hood: Prince of Thieves',
#  'Doctor Zhivago': 'Dead Like Me: Season 2',
#  'Circle of Friends': 'Queer as Folk: Season 1',
#  'Death Becomes Her': 'Secondhand Lions',
#  'Miss Congeniality': 'Mr. Magoo',
#  'Crooklyn': 'Coach Carter',
#  'Zoolander': "Lemony Snicket's A Series of Unfortunate Events",
#  'Police Academy: Special Edition': 'Bill Cosby: Himself',
#  'Full Metal Jacket': 'Four Weddings and a Funeral',
#  'Jawbreaker': 'Lock, Stock and Two Smoking Barrels',
#  'American Pie': 'Three Musketeers',
#  'An American Werewolf in London': 'The Simpsons: Season 6',
#  'Just Cause': 'Pay It Forward',
#  'The Ghost and the Darkness': 'The Incredibles',
#  'Midsomer Murders: The Electric Vendetta': 'Lord of the Rings: The Two Towers: Extended Edition',
#  "Logan's Run": 'Those Magnificent Men in Their Flying Machines',
#  'Super Size Me': 'The Good, the Bad and the Ugly',
#  'Batman: Mask of the Phantasm': 'Lord of the Rings: The Two Towers: Extended Edition',
#  'Die Hard': 'A Night at the Opera',
#  'High Crimes': 'Lock, Stock and Two Smoking Barrels',
#  'The Lost Boys: Special Edition': 'Dead Poets Society',
#  'The Woman in Red': 'One Crazy Summer',
#  'The Pacifier': 'White Heat',
#  'Rushmore': 'Nothing to Lose',
#  'We Were Soldiers': 'Big',
#  "Wayne's World": 'Basic',
#  'A Walk in the Clouds': 'Out of Africa',
#  'Pearl Harbor': 'GoodFellas: Special Edition',
#  'The Motorcycle Diaries': 'Terminator 2: Extreme Edition',
#  'Croupier': 'City of God',
#  'Hide and Seek': 'Saved by the Bell: Season 1',
#  'Unforgiven': 'The Matrix: Revolutions',
#  'The Princess Diaries (Widescreen)': 'Spartan',
#  'Uptown Girls': 'The Village',
#  'The Parent Trap': 'For the Boys',
#  'Face/Off': 'Star Wars: Clone Wars: Vol. 1',
#  'Risky Business': 'Indochine',
#  'Speed': 'Scratch',
#  'Minority Report': 'Casper',
#  'House of Flying Daggers': 'Law & Order: Special Victims Unit: The Fifth Year',
#  'Posse': 'Pay It Forward',
#  'Tuff Turf': "Trainspotting: Collector's Edition",
#  "Bill & Ted's Bogus Journey": 'Hook',
#  'U-571': 'For Your Eyes Only',
#  'The Quiet American': 'Nowhere in Africa',
#  'Gangs of New York': 'Simon Birch',
#  'The Longest Yard': 'Something the Lord Made',
#  'Adaptation': "Aliens: Collector's Edition",
#  'Slums of Beverly Hills': 'Radio Flyer',
#  'The Magdalene Sisters': 'The Station Agent',
#  'Volcano': 'A Streetcar Named Desire',
#  'Waterworld': 'GoldenEye',
#  'The Matrix': 'Hercules',
#  'Man on the Moon': 'Lonesome Dove',
#  '12 Angry Men': "Dead Men Don't Wear Plaid",
#  'October Sky': 'The Best of Friends: Vol. 4',
#  'Blade Runner': 'Some Kind of Wonderful',
#  'The Leopard (English Dubbed Version)': 'The Leopard (Original Italian Version)',
#  'From Russia With Love': 'U.S. Marshals',
#  'I Love You, I Love You Not': 'Amadeus',
#  "Lemony Snicket's A Series of Unfortunate Events": 'The Adventures of Robin Hood',
#  'Wrong Turn': 'Mommie Dearest',
#  'Racing Stripes': "Hell's Angels",
#  'Coming to America': 'Wild Things',
#  'The Doors': 'Northern Exposure: Season 1',
#  'Elf': 'Scream 3',
#  'Stir of Echoes': 'The Santa Clause',
#  'Cocoon: The Return': 'Frankie and Johnny',
#  'The Story of Us': 'Lilo and Stitch',
#  'High Roller: The Stu Ungar Story': 'Pretty Woman',
#  'Shaolin Soccer': 'High Fidelity',
#  'The Debut': 'Rob Roy',
#  'Lord of the Rings: The Two Towers': 'The Cowboys',
#  'Grease': 'Airplane II: The Sequel',
#  'Batman & Robin': 'Rocky V',
#  'The Road to El Dorado': 'Poltergeist',
#  'The Full Monty': 'Parenthood',
#  'The Music Man': 'Star Trek: The Next Generation: Season 7',
#  "Schindler's List": 'Guarding Tess',
#  "The President's Man": 'The Bad and the Beautiful',
#  'The Rock': 'Chinatown',
#  'Fried Green Tomatoes': 'The West Wing: Season 3',
#  'Life or Something Like It': 'Office Space',
#  'The Shawshank Redemption: Special Edition': 'Collateral',
#  'Executive Decision': 'The Love Letter',
#  'Traffic': 'The Blair Witch Project',
#  'The Perfect Score': 'Along Came a Spider',
#  'The Bridges of Madison County': 'Poltergeist',
#  'What Women Want': 'King of the Hill: Season 1',
#  "The Avengers '66": 'The Gnome-Mobile',
#  'The Cider House Rules': 'Naked Gun 33 1/3: The Final Insult',
#  'Bringing Down the House': 'The Cookout',
#  'Firestorm': 'Dr. Martin Luther King, Jr.: A Historical Perspective',
#  'Apollo 13': 'The Commitments',
#  'Heartbreakers': 'Life as a House',
#  'Crimson Tide': 'Gladiator',
#  'Dodgeball: A True Underdog Story': 'Dazed and Confused',
#  'The Cabinet of Dr. Caligari': 'Red Dwarf: Series 3',
#  'The Others': 'Britney Spears: Britney in Hawaii: Live and More',
#  'Friday the 13th: Part 5: A New Beginning': 'Princess Mononoke',
#  'The Time Machine': 'Serendipity',
#  'The Forgotten': 'Stargate SG-1: Season 7',
#  'Born on the Fourth of July': 'Steel Magnolias',
#  'Rocky': 'Smallville: Season 2',
#  "National Lampoon's Animal House": 'Winged Migration',
#  'The Beguiled': 'Start the Revolution Without Me',
#  'Troy': 'Kicking & Screaming',
#  'Kill Bill: Vol. 1': 'The Jewel of the Nile',
#  'Westworld': 'Better Off Dead',
#  'The Borrowers': "Logan's Run",
#  'Defending Your Life': 'Seven',
#  'The Natural': 'The Godfather, Part III',
#  'Forever Young': "Singin' in the Rain",
#  'Bird on a Wire': 'Conspiracy Theory',
#  'Rebel Without a Cause: Special Edition': 'Snatch',
#  'Air Bud: Golden Receiver': 'Crash',
#  'The First Deadly Sin': 'Fried Green Tomatoes',
#  'Sweet and Lowdown': 'Kill Bill: Vol. 2',
#  'Mission: Impossible II': "Bram Stoker's Dracula",
#  'GoodFellas: Special Edition': "Charlotte's Web",
#  'Family Guy: Vol. 2: Season 3': 'Richard Pryor: Live on the Sunset Strip',
#  'Vertical Limit': 'Legend of 1900',
#  'Master and Commander: The Far Side of the World': 'Seven',
#  "Murphy's Romance": 'The Professional',
#  'Lethal Weapon 4': 'Three Musketeers',
#  'Spun': 'Crouching Tiger, Hidden Dragon',
#  'Central Station': 'Friends: Season 6',
#  'Calendar Girls': 'Edward Scissorhands',
#  'A Thousand Acres': 'Sommersby',
#  'Caddyshack': 'Michael',
#  'MASH: Season 3': 'Jersey Girl',
#  'Malice': "A Bug's Life",
#  'Rush': 'Dawn of the Dead',
#  'Murder on the Orient Express': 'The Godfather, Part II',
#  'Mixed Nuts': 'The Italian Job',
#  'The Hunchback of Notre Dame': '24: Season 1',
#  'Three Musketeers': 'A Little Princess',
#  'Punch-Drunk Love': 'Lucas',
#  'The Right Stuff': 'The Godfather',
#  'Friday': "That '70s Show: Season 1",
#  'First Knight': 'The Good, the Bad and the Ugly',
#  'The Princess Bride': 'Baby Boom',
#  'Hardball': 'Dirty Dancing',
#  'Comedian': 'Before Sunset',
#  'Farscape: Season 3': 'Lexx: Series 2',
#  'The Best of Friends: Season 4': 'Hudson Hawk',
#  'The Upside of Anger': 'Coming Home',
#  'My Big Fat Greek Wedding': 'Reality Bites',
#  "Monster's Ball": 'Raising Helen',
#  'The Usual Suspects': 'The Long, Hot Summer',
#  'Eraser': 'The Alien Saga',
#  'George Carlin: Personal Favorites': 'Richard Pryor: Live on the Sunset Strip',
#  'Stroszek': 'Aguirre: The Wrath of God',
#  'Hitch': "Alien: Collector's Edition",
#  'The Maltese Falcon': 'The Shadow',
#  'Contact': 'The Importance of Being Earnest',
#  "Malibu's Most Wanted": 'Cedric the Entertainer: Starting Lineup',
#  'CSI: Season 3': 'Star Trek: The Next Generation: Season 7',
#  "George Carlin: Jammin' in New York / Doin' It Again": 'The American President',
#  'The Sisterhood of the Traveling Pants': 'The Lion King: Special Edition',
#  'Liar Liar': 'The Whole Nine Yards',
#  'Aladdin: Platinum Edition': 'My Man Godfrey',
#  'Meet Joe Black': 'Austin Powers: International Man of Mystery',
#  'The World Is Not Enough': 'Groundhog Day',
#  'Braveheart': 'Operation Pacific',
#  "The Emperor's New Groove": 'King of the Hill: Season 1',
#  "Charlie's Angels": 'K-9',
#  'Addams Family Values': 'Children of the Corn',
#  'Lethal Weapon': "One Flew Over the Cuckoo's Nest",
#  'Conspiracy Theory': 'The Program',
#  'Rebecca': 'Three Musketeers',
#  'Envy': 'Independence Day',
#  'The Lion King 1 1/2': 'The Adventures of Baron Munchausen',
#  'Eddie and the Cruisers': 'Parenthood',
#  'Steve Harvey: One Man': 'Hero',
#  'Mad Max Beyond Thunderdome': "Wayne's World",
#  'The Secret Garden': 'Once Upon a Time in Mexico',
#  "Something's Gotta Give": '9/11',
#  'Empire Records: Remix! Special Fan Edition': 'City Lights',
#  'Basic Instinct': "Outfoxed: Rupert Murdoch's War on Journalism",
#  'Arthur': 'The Santa Clause 2',
#  'Dave': 'The Trouble with Angels',
#  'Broken Arrow': 'Roman Holiday',
#  'A Mighty Wind': 'Big Bad Love',
#  'Around the World in 80 Days': 'The Princess Diaries (Fullscreen)',
#  'Mr. 3000': 'Citizen X',
#  'Hard to Kill': 'Three Days of the Condor',
#  'For Your Eyes Only': 'Aladdin: Platinum Edition',
#  'Little Shop of Horrors': 'Lucio Fulci: The Beyond',
#  'Psycho': "Outfoxed: Rupert Murdoch's War on Journalism",
#  'Scarface: 20th Anniversary Edition': 'Steel Magnolias',
#  'Milk Money': 'Gladiator',
#  'Cold Mountain': 'Extreme Measures',
#  'High Fidelity': 'Pistol Opera',
#  'Deep Impact': "Chappelle's Show: Season 1",
#  'Deliverance': 'The Last Temptation of Christ',
#  'Bill Hicks Live: Satirist, Social Critic, Stand-up Comedian': "Charlotte's Web",
#  'Catwoman': 'Metallica: Some Kind of Monster',
#  "The Crying Game: Collector's Edition": "Monty Python's Life of Brian",
#  'Love & Basketball': 'All Quiet on the Western Front',
#  "Von Ryan's Express": 'Braveheart',
#  'Willow': 'Garden State',
#  'Assault on Precinct 13': 'Absolute Power',
#  'Antwone Fisher': 'Crooklyn',
#  'Poetic Justice': 'Rush Hour 2',
#  'Men in Black': 'Disclosure',
#  'Secret Window': 'Jimmy Neutron: Boy Genius',
#  'Gattaca': 'The Rundown',
#  'Sex and the City: Season 4': 'Rush Hour 2',
#  'History of the World: Part 1': 'Roger & Me',
#  'U.S. Marshals': 'Pulp Fiction',
#  'Just Married': 'Curly Sue',
#  'Austin Powers: International Man of Mystery': 'The Boondock Saints',
#  'A Day Without a Mexican': 'The Trip',
#  'The Adventures of Milo and Otis': 'Gone in 60 Seconds',
#  'Sex and the City: Season 1': 'The Nightmare Before Christmas',
#  '1984': 'The Thin Red Line',
#  'Gothika': 'The Sound of Music',
#  'Dog Day Afternoon': 'Saturday Night Live: The Best of Will Ferrell',
#  'Amadeus': 'The Taming of the Shrew',
#  'Bowfinger': 'Silkwood',
#  "Big Momma's House": 'Elvira, Mistress of the Dark',
#  'Dark Angel: Season 1': '50 First Dates',
#  'X2: X-Men United': 'Roger & Me',
#  'Mr. Deeds': 'Along Came Polly',
#  'Sleepers': 'Persuasion',
#  'Audition': 'Innocence',
#  'The Tuskegee Airmen': 'The Alamo',
#  'Raw': 'Jack',
#  'Twins': "Bram Stoker's Dracula",
#  'True Lies': '20,000 Leagues Under the Sea',
#  '48 Hrs.': 'Mars Attacks!',
#  'Sesame Street: Elmopalooza!': 'The Simpsons: Treehouse of Horror',
#  'Constantine': 'J.R.R. Tolkien and the Birth of The Lord of the Rings',
#  'Sweet Home Alabama': 'The Night of the Hunter',
#  'Double, Double, Toil and Trouble': 'The Land Before Time VII: Stone of Cold Fire',
#  'Coach Carter': 'Kill Bill: Vol. 2',
#  'The Karate Kid': 'Star Wars: Episode V: The Empire Strikes Back',
#  'Mary-Kate & Ashley: The Challenge': 'G.I. Jane',
#  'I Heart Huckabees': 'Eddie Izzard: Circle',
#  'Lethal Weapon 2': "Singin' in the Rain",
#  'The Pajama Game': 'Million Dollar Baby',
#  'Lilo and Stitch': 'Justice League',
#  'Little Big League': 'The Rundown',
#  'The Trouble with Angels': 'Blue Hawaii',
#  'The Shining': 'The Animatrix',
#  'The Legend of Hell House': 'The Thin Man Goes Home',
#  'Agent Cody Banks 2: Destination London': 'Miracle',
#  'Star Wars: Episode V: The Empire Strikes Back': "Jane Goodall's Wild Chimpanzees: IMAX",
#  'Born Yesterday': 'The English Patient',
#  'Legally Blonde': 'A Cinderella Story',
#  'The Punisher': 'CSI: Season 1',
#  'Babylon 5: A Call to Arms': 'CSI: Season 1',
#  'Fire Birds': 'U.S. Marshals',
#  'Waiting for Guffman': "Pee-Wee's Big Adventure",
#  'Maria Full of Grace': 'Fahrenheit 451',
#  'Shall We Dance?': 'Bad Boys II',
#  'Harry Potter and the Chamber of Secrets': 'The West Wing: Season 1',
#  'Robin Williams: Live on Broadway': 'Gladiator: Extended Edition',
#  'Shallow Hal': 'Tommy Boy',
#  'Fever Pitch': 'E.T. the Extra-Terrestrial: The 20th Anniversary (Rerelease)',
#  "Can't Hardly Wait": 'Sense and Sensibility',
#  "Porky's": 'The Fugitive',
#  'White Squall': 'Lord of the Rings: The Two Towers',
#  'To Sir, with Love': 'This Is Spinal Tap',
#  'I, Robot': "The Wizard of Oz: Collector's Edition",
#  'The Fog of War': 'The Vikings',
#  'Friends: Season 2': 'Rocky V',
#  'Johnny Be Good': 'Fantasia 2000',
#  'The Best of Friends: Season 3': 'Bride and Prejudice',
#  'Ghost in the Shell': 'Pirates of the Caribbean: The Curse of the Black Pearl',
#  'Runaway': 'Frida',
#  'Anger Management': 'Out of Africa',
#  'Seven Samurai': 'The Rundown',
#  'Spartacus': 'Out of Sight',
#  'Hotel Rwanda': 'Freaks & Geeks: The Complete Series',
#  'Sin City': 'Unleashed',
#  'Edward Scissorhands': 'Dirty Dancing',
#  'Maid in Manhattan': 'Roman Holiday',
#  'Camille Claudel': 'Aladdin: Platinum Edition',
#  'Radio': 'Taxi',
#  'Superman: The Movie': 'Roger & Me',
#  'Kickboxer': 'Superstar',
#  'The Paper': 'Saw',
#  'The Sopranos: Season 3': 'Finding Neverland',
#  'The Sweet Hereafter': 'Fight Club',
#  'Runaway Bride': 'Ghost Dog: The Way of the Samurai',
#  'Rough Air': 'The Usual Suspects',
#  'Death Wish': 'Highlander: Season 4',
#  'The Crossing Guard': 'The Thin Red Line',
#  'The Nutty Professor': "Bridget Jones's Diary",
#  'Office Space': "What's Eating Gilbert Grape",
#  'The Bourne Identity': 'Guarding Tess',
#  'Better Off Dead': '25th Hour',
#  'The Freshman': 'The King and I',
#  'Ransom': "ABC Primetime: Mel Gibson's The Passion of the Christ",
#  'Shaun of the Dead': 'Love Comes Softly',
#  'Treasure Planet': 'Dogma',
#  'Snake Eyes': 'A Night at the Opera',
#  'Nothing to Lose': 'Man on the Moon',
#  'Bicentennial Man': 'Evil Dead 2: Dead by Dawn',
#  'ER: Season 1': 'Edward Scissorhands',
#  'While You Were Sleeping': 'Harold and Maude',
#  'Blade: Trinity': 'Dragonheart',
#  'Austin Powers: The Spy Who Shagged Me': "The Devil's Brigade",
#  'Nicholas Nickleby': 'Rudy',
#  "Recess: School's Out": 'Secondhand Lions',
#  'Father of the Bride': 'Army of Darkness',
#  'The Man Without a Past': 'Roger & Me',
#  'Airplane II: The Sequel': 'Jagged Edge',
#  'Star Trek: The Next Generation: Season 3': 'Dogma',
#  'Best of The Muppet Show: Mark Hamill / Paul Simon / Raquel Welch': 'Best of The Muppet Show: Peter Sellers / John Cleese / Dudley Moore',
#  'Thoroughly Modern Millie': 'Dirty Rotten Scoundrels',
#  'Taxi': 'The Red Violin',
#  'The Mummy': 'Meet the Fockers',
#  'Panic Room': 'The Godfather, Part II',
#  'Indiana Jones and the Temple of Doom': 'War Games',
#  'The Interpreter': 'Rudy',
#  'Magnum Force': 'Armageddon',
#  'Zombie': 'Dawn of the Dead',
#  "Teacher's Pet": 'Shrek (Full-screen)',
#  'Raising Helen': 'Back to the Future Part III',
#  'Prick Up Your Ears': 'Sex and the City: Season 4',
#  'Old School': 'L.A. Confidential',
#  'Bring It On': 'Touched by an Angel: Season 1',
#  'The Odd Couple': 'The Best of the New Scooby-Doo Movies',
#  'La Femme Nikita': 'Drugstore Cowboy',
#  'The Truman Show': 'The Spanish Prisoner',
#  'Princess Mononoke': 'The Great Race',
#  'The Twilight Zone: Vol. 15': 'Mannequin',
#  'Farscape: Season 2': 'Hopscotch',
#  'Galaxy Quest': 'Mary Poppins',
#  'Gone in 60 Seconds': 'Deadwood: Season 1',
#  'Chitty Chitty Bang Bang': 'Turbulence',
#  'Fight Club': 'Philadelphia',
#  'Flubber': 'The West Wing: Season 1',
#  'Dirty Harry': 'Halloween: H2O',
#  'The Prophecy': 'Dogma',
#  'Good Morning, Vietnam': 'Who Framed Roger Rabbit?: Special Edition',
#  'Dracula 2000': 'Scream 3',
#  'Rugrats in Paris: The Movie': 'Ever After: A Cinderella Story',
#  'Along Came a Spider': 'Last Man Standing',
#  'Anchorman: The Legend of Ron Burgundy': 'The Third Man',
#  'Two Mules for Sister Sara': 'Rob Roy',
#  'Alive': 'Roger & Me',
#  'Say Anything': "National Lampoon's Van Wilder",
#  'City Slickers': 'The Parent Trap',
#  'Patriot Games': "America's Sweethearts",
#  'Sleepover': 'Freaky Friday',
#  'Gidget Goes Hawaiian / Gidget Goes to Rome': 'Fantasia 2000',
#  'Amelie': 'If These Walls Could Talk',
#  'Twisted': 'Sting: The Brand New Day Tour',
#  'Final Destination': 'The O.C.: Season 1',
#  'The Firm': 'Crazy/Beautiful',
#  'I Am Trying to Break Your Heart: A Film About Wilco': 'Igby Goes Down',
#  'Diamond Men': 'Once Upon a Time in the West',
#  'Kiss the Girls': 'Star Trek: Voyager: Season 5',
#  'The NeverEnding Story': 'Diary of a Mad Black Woman',
#  'Someone Like You': 'Lupin the 3rd',
#  'The Hudsucker Proxy': 'Wag the Dog',
#  'Bend It Like Beckham': 'The Wedding Planner',
#  'The Tall Guy': 'This Is Spinal Tap',
#  'Spy Kids': 'Gladiator',
#  'The Boondock Saints': 'Lord of the Rings: The Return of the King: Extended Edition',
#  'The Deep': 'The Exorcist: Restored Version',
#  'Sky Captain and the World of Tomorrow': 'Funny Face',
#  'Transformers: The Movie': 'The Shield: Season 2',
#  'Tootsie': 'Man on Fire',
#  'Enigma': 'Stigmata',
#  'The Rage: Carrie 2': 'Richard Pryor: Live on the Sunset Strip',
#  'Steel Magnolias': 'Caddyshack',
#  'Inspector Gadget 2': 'The Tick: The Entire Series',
#  'Peter Pan': 'The Triplets of Belleville',
#  'Eternal Sunshine of the Spotless Mind': 'Strangers with Candy: Season 3',
#  'That Thing You Do!': 'The Lion King: Special Edition',
#  'Big Daddy': 'Cowboy Bebop Remix',
#  'Magnolia': 'Ikiru',
#  'The World According to Garp': 'Forrest Gump',
#  'The Pink Panther Strikes Again': 'Clerks',
#  "Can't Buy Me Love": "That '70s Show: Season 1",
#  'Philadelphia': 'The Royal Tenenbaums',
#  'Bedazzled': 'The Remains of the Day',
#  'The King and I': "Wayne's World",
#  'Lost in Translation': 'Indochine',
#  'Harvey': "Aliens: Collector's Edition",
#  'Friends: Season 4': 'Top Gun',
#  'Die Another Day': 'Die Monster Die!',
#  'Underworld': 'Clarissa Explains It All: Season 1',
#  'Candyman 2: Farewell to the Flesh': 'Shaun of the Dead',
#  'Letters From a Killer': 'Speed',
#  'Mean Girls': 'The Godfather',
#  "Jesus' Son": 'The Dead Zone: Season 2',
#  'True Crime': 'Memento',
#  'Proof of Life': 'Remember the Titans',
#  'You Only Live Twice': 'The Looney Tunes Golden Collection: Vol. 2',
#  'The Pianist': 'As Good as It Gets',
#  'Anaconda': 'Lock, Stock and Two Smoking Barrels',
#  "St. Elmo's Fire": 'Friends: Season 3',
#  'Once Upon a Time in Mexico': 'Batman Beyond: The Movie',
#  'Babylon 5: Season 3': 'Saturday Night Live: The Best of Eddie Murphy',
#  'Sleepless in Seattle': "Monty Python's Life of Brian",
#  'To Die For': 'What Lies Beneath',
#  "My Best Friend's Wedding": 'Crash',
#  'South Park: Passion of the Jew': 'The Game',
#  'The Mighty Ducks': 'The Day After Tomorrow',
#  'Kate & Leopold': 'The Maltese Falcon',
#  'Field of Dreams': 'Pride and Prejudice',
#  'American History X': 'If These Walls Could Talk',
#  'Die Hard With a Vengeance': 'The Triplets of Belleville',
#  'The Fly / The Fly 2': 'Impostor',
#  'Ghost Ship': 'Blade',
#  'Ghosts of the Abyss': 'Rob Roy',
#  'Capturing the Friedmans': 'The Dreamers',
#  'About Schmidt': "One Flew Over the Cuckoo's Nest",
#  'The Legend of Drunken Master': 'Once Upon a Time in China',
#  'Casino: 10th Anniversary Edition': 'The Prime of Miss Jean Brodie',
#  'Benny Goodman: Adventures in the Kingdom of Swing': 'The Deer Hunter',
#  "Harry Potter and the Sorcerer's Stone": 'Girls Just Want to Have Fun',
#  'Men of Honor': "Chappelle's Show: Season 1",
#  'Walking Tall': 'Romeo is Bleeding',
#  'Open Range': 'Jack',
#  'Evita': 'Rudolph the Red-Nosed Reindeer',
#  '4 Dogs Playing Poker': 'The Bad and the Beautiful',
#  'Resident Evil: Apocalypse': 'Duplex (Widescreen)',
#  'Bulletproof Monk': 'Anchorman: The Legend of Ron Burgundy',
#  'Belly of the Beast': 'Eye of the Needle',
#  'Roxanne': 'Ballykissangel: Series 2',
#  'A Lot Like Love': 'The Best of Friends: Season 1',
#  'Payback': 'The Goonies',
#  'Star Trek II: The Wrath of Khan': 'Stalag 17',
#  "Chappelle's Show: Season 2": 'The Grapes of Wrath',
#  'Spy Kids 2: The Island of Lost Dreams': 'Serial Mom',
#  'The Scorpion King': 'The Hunt for Red October',
#  'A Decade Under the Influence': 'The Night of the Hunter',
#  'Big Business': 'I Love Lucy: Season 4',
#  'Dr. Quinn, Medicine Woman: Season 2': 'The Swan Princess',
#  'Operation Condor 2: Armour of the Gods': 'The Warriors',
#  'Gladiator': 'Paycheck',
#  'Erasure: Hits! The Videos': 'Dogma',
#  'Secretary': 'A Walk to Remember',
#  'Short Circuit 2': 'The Matrix: Revolutions',
#  'Chocolat': 'Raging Bull',
#  'Spider-Man 2': 'Major League',
#  "Don't Say a Word": 'Out of Time',
#  'Breaking In': 'Sirens',
#  'Star Wars: Episode I: The Phantom Menace': 'Reality Bites',
#  'Quigley Down Under': "Something's Gotta Give",
#  'On the Waterfront': 'The Adventures of Pete & Pete: Season 1',
#  'Garfield: The Movie': 'If These Walls Could Talk 2',
#  'The Big Lebowski': 'A Mighty Wind',
#  'The Women of Brewster Place': 'Dinosaur Planet',
#  "They Shoot Horses, Don't They?": 'Matewan',
#  'K-Pax': 'The Professional',
#  'Sabrina': 'Dune',
#  'Reality Bites': 'Onmyoji',
#  'White Oleander': 'Groundhog Day',
#  'The Animatrix': 'Killing Words',
#  'Southern Comfort': 'North by Northwest',
#  'The Saint': 'We Were Soldiers',
#  'Band of Brothers': '28 Days Later',
#  'John Q': 'Hook',
#  'Lady and the Tramp': 'The Best of Friends: Vol. 4',
#  'Duets': 'The World According to Garp',
#  'Desperado / El Mariachi': 'Silverado',
#  'American Psycho': 'Ghost in the Shell',
#  'Simply Irresistible': 'Sea of Love',
#  'Saving Private Ryan': 'Freaks & Geeks: The Complete Series',
#  'The Sleeping Dictionary': 'Pirates of the Caribbean: The Curse of the Black Pearl',
#  'Vanilla Sky': 'Firefly',
#  'Blazing Saddles': 'The Lost World: Jurassic Park',
#  'Practical Magic': 'Starman',
#  "Madea's Family Reunion (Stage Play)": 'Mr. 3000',
#  'Dorm Daze': 'The Goonies',
#  "Pee-Wee's Big Adventure": 'Blade',
#  'Specimen': 'Pirates of the Caribbean: The Curse of the Black Pearl',
#  'Murder at 1600': 'Out for Justice',
#  'Thesis': 'X2: X-Men United',
#  'Project X': 'Dragonheart',
#  'The Matrix: Revisited': 'Fame',
#  'Remember the Titans': 'Ladyhawke',
#  "My Baby's Daddy": 'Sweet Home Alabama',
#  'The Godfather, Part II': 'Matewan',
#  'The Return of Swamp Thing': 'Jaws',
#  'The Thin Man': 'Who Framed Roger Rabbit?: Special Edition',
#  'Breakdown': 'The Bridge on the River Kwai',
#  'The Good Girl': 'La Femme Nikita: Season 1',
#  'Tenacious D: Complete Masterworks': 'Ed Wood',
#  'The Dirty Dozen': 'Armageddon',
#  'The Last Samurai': 'The Muppet Movie',
#  'The Count of Monte Cristo': 'Rudy',
#  'The Core': 'Hook',
#  'Serpico': "ABC Primetime: Mel Gibson's The Passion of the Christ",
#  'Harlem Nights': 'Son in Law',
#  'The Rookie': 'The Long Walk Home',
#  'The Thomas Crown Affair': 'American History X',
#  'The Monkees: Season 2': 'The Guns of Navarone',
#  'XXX: Special Edition': 'Team America: World Police',
#  'Dead Poets Society': 'The Lawnmower Man',
#  'Smokey and the Bandit / Smokey and the Bandit II: Double Feature': 'UFC 52: Ultimate Fighting Championship: Randy Couture vs. Chuck Liddell',
#  'Hard Rain': 'Save the Last Dance',
#  'The Distinguished Gentleman': "Rosemary's Baby",
#  'The Secret of My Success': 'Roxanne',
#  'Flatliners': 'Hellbound: Hellraiser II',
#  'The Flight of the Phoenix': 'Young Einstein',
#  'Varsity Blues': 'Flubber',
#  'The Witches of Eastwick': 'Heist',
#  'The Jamie Kennedy Experiment: Season 1': "Chappelle's Show: Season 1",
#  'The Princess Diaries 2: Royal Engagement': 'The Passion of the Christ',
#  'The Postman': 'Signs',
#  'No Way Out': 'Clerks',
#  'Coyote Ugly': 'Last Man Standing',
#  'Soul Man': 'The Last Temptation of Christ',
#  'In the Mouth of Madness': "Mackenna's Gold",
#  'Domestic Disturbance': 'Duplex (Widescreen)',
#  'Mission: Impossible': 'Monarch of the Glen: Series 2',
#  'Pom Poko': 'Sin City',
#  'Best of The Muppet Show: Diana Ross / Brooke Shields / Rudolph Nuryev': 'Aqua Teen Hunger Force: Vol. 1',
#  'S.W.A.T.': 'Elizabeth',
#  'Biggie & Tupac': 'The Carol Burnett Show: Show Stoppers',
#  "Mask: Director's Cut": 'Wild Things',
#  'Ladder 49': 'In Living Color: Season 1',
#  'The O.C.: Season 2': 'The Wedding Planner',
#  'The Hunt for Red October': 'Michael Collins',
#  'The School of Rock': 'An Officer and a Gentleman',
#  'Identity': 'Latter Days',
#  'The Muse': "Bridget Jones's Diary",
#  'Flight of the Navigator': 'The Best of Friends: Vol. 4',
#  'Nick of Time': 'Pretty Woman',
#  'Rivers and Tides': 'The Woodsman',
#  'Lost in Space': 'The Siege',
#  'Gone But Not Forgotten': 'Cat Stevens: Majikat',
#  'The Family Man': 'The Bad and the Beautiful',
#  'Oh God!': 'The Twilight Zone: Vol. 27',
#  'Mr. Show: Season 4': 'Identity',
#  'Thirteen Days': 'Dangerous Beauty',
#  'Gossip': 'Bear Cub',
#  'Inu-Yasha: The Movie: Affections Touching Across Time': 'The 10th Kingdom',
#  'Jack': 'Chobits',
#  'Four Rooms': 'Fame',
#  'Little Women': 'Last Man Standing',
#  'Cold Creek Manor': 'Seabiscuit',
#  'The Return of the Pink Panther': 'Garden State',
#  'Hero': 'American Wedding',
#  'Phone Booth': 'A Cinderella Story',
#  '20,000 Leagues Under the Sea': "Charlotte's Web",
#  'In America': 'The Matrix',
#  'Road Trip': 'Krull',
#  'The Last Waltz': 'Goldfinger',
#  'Mister Roberts': 'Open Range',
#  'Talk to Her': 'Spartan',
#  "Captain Corelli's Mandolin": 'Three Men and a Baby',
#  'In the Line of Fire': 'The Great Escape',
#  'Batteries Not Included': 'Parenthood',
#  "National Lampoon's Van Wilder": 'Blue Collar Comedy Tour: The Movie',
#  "America's Sweethearts": 'A Night at the Opera',
#  'Evolution': 'The Patriot',
#  'Kill Bill: Vol. 2': 'The Daily Show with Jon Stewart: Indecision 2004',
#  'Selena': "Schindler's List",
#  'The Virgin Suicides': 'Rambo: First Blood Part II',
#  'Shark Tale': 'Catch Me If You Can',
#  'House on Haunted Hill': 'Dead Ringers',
#  'Sons of Katie Elder': 'Major League',
#  'Monty Python: The Life of Python': 'Evil Dead 2: Dead by Dawn',
#  'Mr. Mom': 'Gone in 60 Seconds',
#  'Saturday Night Live: The Best of Eddie Murphy': 'Pirates of the Caribbean: The Curse of the Black Pearl',
#  'The Phantom of the Opera': 'Duplex (Widescreen)',
#  'Bliss': 'Heathers',
#  'Sleepy Hollow': 'An American Tail',
#  'Pennies from Heaven': 'Coach Carter',
#  'The Man Who Fell to Earth': 'Men in Black II',
#  'Aloha Scooby-Doo!': 'X2: X-Men United',
#  'It Could Happen to You': "That '70s Show: Season 1",
#  'Star Trek: The Original Series: Vols. 16-28': 'Lord of the Rings: The Fellowship of the Ring',
#  'The 6th Man': '44 Minutes',
#  'Fatal Attraction': 'Star Trek: The Next Generation: Season 7',
#  "We Don't Live Here Anymore": 'The Wire: Season 1',
#  'One Hour Photo': 'Bonnie and Clyde',
#  'A Cinderella Story': 'Sex and the City: Season 6: Part 2',
#  'Gremlins 2: The New Batch': 'Bend It Like Beckham',
#  'Rambo: First Blood Part II': 'Dr. Strangelove',
#  'Mighty Aphrodite': 'Mrs. Doubtfire',
#  'Scarface': 'Heat: Special Edition',
#  'Das Boot': 'Stalag 17',
#  'The Karate Kid Part II': 'Angel and the Badman',
#  'The Legend of Bagger Vance': 'The Musketeer',
#  'Free Willy 2: The Adventure Home': 'Men in Black II',
#  'Apocalypse Now Redux': 'Apollo 13',
#  'Desperately Seeking Susan': 'Sexual Matrix',
#  'The Big Chill': 'Overboard',
#  'Pretty Woman': 'The Lost Boys: Special Edition',
#  'Seven': "But I'm a Cheerleader",
#  'Happy Gilmore': 'The Matrix: Revolutions',
#  'The Kid': 'Jimmy Neutron: Boy Genius',
#  'Basic': 'Liar Liar',
#  'A.I. Artificial Intelligence': 'Strange Days',
#  'The Dead Zone': "Chappelle's Show: Season 1",
#  'Nine to Five': 'What the #$*! Do We Know!?',
#  'The Last of the Mohicans': 'Scary Movie',
#  'Scent of a Woman': 'Elmer Gantry',
#  'The Good Son': 'Firestarter',
#  'Son in Law': 'Classic Cartoon Favorites: Starring Donald',
#  'The Twilight Zone: Vol. 40': "Rosemary's Baby",
#  'Requiem for a Dream': 'Crooklyn',
#  'Austin Powers in Goldmember': 'Moonstruck',
#  'Bounce': 'The Hurricane',
#  'Into the Arms of Strangers: Stories of the Kindertransport': 'Cinemania',
#  'V: The Original Miniseries': "Something's Gotta Give",
#  'Code of Silence': 'The Fast and the Furious',
#  "Gone with the Wind: Collector's Edition": 'Days of Heaven',
#  'Chicago': 'Silver Bullet',
#  'Support Your Local Sheriff!': 'Blade: Trinity',
#  "Rosemary's Baby": 'The Wedding Planner',
#  'The Best of Friends: Season 2': 'The Chorus',
#  'Dangerous Liaisons': "It's the Great Pumpkin, Charlie Brown",
#  'Species': 'Mannequin',
#  'Tenchi the Movie 2: Daughter of Darkness': 'Yu Yu Hakusho',
#  'Fletch': 'The Simpsons: Season 1',
#  'City of Angels': 'The Fog of War',
#  'Star Wars: Clone Wars: Vol. 1': 'Pulp Fiction',
#  'The Simple Life: Season 1': 'Dinosaur Planet',
#  'Trading Places': 'Hocus Pocus',
#  'The Phantom of the Opera: Special Edition': "Bridget Jones's Diary",
#  'Scream 2': 'The Poseidon Adventure',
#  'Joy Ride': 'Harlem Nights',
#  'For Love of the Game': 'Summer Rental',
#  'Rudy': 'Buffy the Vampire Slayer: Season 6',
#  'The Road Warrior': 'Scent of a Woman',
#  'CSI: Miami: Season 1': 'South Park: Season 2',
#  'Hulk': 'Jurassic Park',
#  'Under Siege 2: Dark Territory': 'S.W.A.T.',
#  'Signs': 'Lost in Translation',
#  'Demolition Man': "Mask: Director's Cut",
#  'A Murder of Crows': 'High Tension',
#  "Things to Do in Denver When You're Dead": 'Richard III',
#  'Tommy Boy': 'Training Day',
#  '12 Monkeys': 'The English Patient',
#  "Sheryl Crow: Rockin' the Globe Live": 'Head: The Monkees',
#  'A Perfect Murder': "The Wizard of Oz: Collector's Edition",
#  'Summer School': 'The Wedding Planner',
#  'Be Cool': 'Jaws',
#  'Salvador': 'Das Boot',
#  'Stander': 'Bottle Rocket',
#  'Double Jeopardy': 'Sleeping With the Enemy',
#  'Slap Shot 2: Breaking the Ice': 'Parenthood',
#  'Homicide: Life on the Street: Season 3': 'Star Trek: Voyager: Season 1',
#  'Mifune': 'Chariots of Fire',
#  'How Green Was My Valley': 'Dirty Rotten Scoundrels',
#  'Here on Earth': 'The Last Samurai',
#  'The Exorcist': 'Flesh Gordon',
#  'Rounders': 'Happiness',
#  'Three Men and a Little Lady': 'The Mummy',
#  'Moonstruck': 'An Evening With Kevin Smith',
#  'Body Heat': 'Memento',
#  'An Extremely Goofy Movie': 'Braveheart',
#  'Dickie Roberts: Former Child Star': 'S.I.C.K.',
#  'The Man Who Knew Too Much': 'The Magnificent Seven',
#  'Empire': 'Rush Hour 2',
#  'Possessed': 'Frida',
#  'EDtv': 'While You Were Sleeping',
#  'The Cutting Edge': 'My Favorite Brunette',
#  'VeggieTales Classics: Rack, Shack and Benny': 'American Beauty',
#  "Boys Don't Cry": 'Annie: Special Anniversary Edition',
#  'Glengarry Glen Ross': 'Life or Something Like It',
#  'Saturday Night Live: The Best of Will Ferrell': 'Pirates of the Caribbean: The Curse of the Black Pearl',
#  'Five Deadly Venoms': 'Dragon Ball GT',
#  'Lord of the Rings: The Return of the King': 'Cowboy Bebop: The Movie',
#  'Beyond Borders': 'Heat: Special Edition',
#  'Alfie': 'The Turning Point',
#  'Samurai Trilogy 2: Duel at Ichijoji Temple': 'The Program',
#  'The Bachelor': 'The Mummy',
#  'Pet Sematary 2': 'Coupling: Season 2',
#  'Sleuth': 'A Night at the Opera',
#  'Rocky III': 'Man on the Train',
#  'Sahara': "A Hard Day's Night: Collector's Series",
#  'Around the Bend': 'Lonesome Dove',
#  'The Negotiator': 'Woman Thou Art Loosed',
#  'Lord of the Rings: The Two Towers: Extended Edition': 'Bottle Rocket',
#  'Van Helsing': 'Congo',
#  'Bad Boys': 'Screamers',
#  'Jungle 2 Jungle': "American Graffiti: Collector's Edition",
#  'Terminator 3: Rise of the Machines': 'Cats & Dogs',
#  'Knockaround Guys': 'Hostage',
#  '13 Going on 30': 'Rugrats All Grown Up: Growing Up Changes Everything',
#  'Cellular': 'Star Wars: Episode V: The Empire Strikes Back',
#  'Backdraft': 'No Way Out',
#  'The Lion King: Special Edition': 'The Bourne Supremacy',
#  'Atlantis: The Lost Empire': 'The Ninth Gate',
#  'This Is Spinal Tap': 'The American President',
#  'Volunteers': 'Aladdin: Platinum Edition',
#  'Dune': 'Devo: The Complete Truth About De-evolution',
#  'South Park: Bigger, Longer and Uncut': 'High Fidelity',
#  '28 Days Later': 'Lord of the Rings: The Fellowship of the Ring',
#  'Mad About You: Season 2': 'Star Wars: Episode V: The Empire Strikes Back',
#  'Mystery Science Theater 3000: Hercules Unchained': 'Hotel Rwanda',
#  'Exit Wounds': 'Impostor',
#  'The Jerk': 'A Clockwork Orange',
#  'Body Snatchers': 'The Game',
#  'The Way of the Gun': 'Simpsons Gone Wild',
#  'Napoleon Dynamite': 'Transformers: Season 3: Part 1',
#  'Patton': 'Hollow Man',
#  ...}

# %%
# EJECUTAMOS EL AGENTE EN ESCENARIO DE USAR LA POLÍTICA APRENDIDA EN ENTRENAMIENTO

env = Environment(data, read_movie_titles(r"Netflix_Prize_data\movie_titles.csv"))

# Cargamos la política aprendida
qtable = load_qtable('qtable.json')

# creación del agente y pasamos la política como parámetro 'qtable'
# En esta ocasión vamos a utilizar un valor de exploración pequeño (epsilon),
# con el fin de que el agente explote la política encontrada lo más posible.
agent = Agent(env, gamma=0.9, alpha=0.1, epsilon=0.1, episodes=500, qtable=qtable) 

#ejecución del agente
agent.run()
actions, values, recommended = agent.actions_values()
recommended
# Out:
# {'Woman on Top': 'Greenfingers',
#  'Greenfingers': 'Stir Crazy',
#  'Stir Crazy': "The Devil's Brigade",
#  "The Devil's Brigade": 'CSI: Season 1',
#  'CSI: Season 1': 'A Night at the Opera',
#  'A Night at the Opera': 'Clerks',
#  'The Women': 'Ed Wood',
#  'Ed Wood': "Donnie Darko: Director's Cut",
#  "Donnie Darko: Director's Cut": 'Ordinary People',
#  'Ordinary People': 'Six Degrees of Separation',
#  'Six Degrees of Separation': 'A Night at the Opera',
#  'Clerks': 'La Buche',
#  'La Buche': 'Alias: Season 3',
#  'Raw': 'The Pacifier',
#  'Dark Command': 'Touched by an Angel: Season 1',
#  'Johnny Be Good': 'Jesus of Nazareth',
#  "Don't Say a Word": "The Devil's Backbone",
#  'Braveheart': 'Raising Arizona',
#  'The Stepford Wives': 'Indochine',
#  'Mr. Deeds': 'Dr. Dolittle 2',
#  'The Diary of Anne Frank': 'Dragonheart',
#  'The Jackal': 'The Killers: Criterion Collection',
#  'The Godfather': 'The Three Stooges: Three Smart Saps',
#  'Kung Fu Hustle': 'A Streetcar Named Desire',
#  'In the Cut': 'A Fistful of Dollars',
#  'Cocktail': "National Lampoon's Animal House",
#  'Billy Joel: Greatest Hits: Vol. 3: The Video': 'Luther Vandross: Always and Forever: An Evening of Songs',
#  'Bandits': 'Deadwood: Season 1',
#  "Let's Do It Again": 'The Man Without a Face',
#  'Old School': 'Coach Carter',
#  'Master and Commander: The Far Side of the World': 'Conman',
#  'The Last Samurai': 'Fried Green Tomatoes',
#  'Enemy of the State': 'High School High',
#  'Kingdom of Heaven': 'In the Mood for Love',
#  'Shallow Hal': 'Finding Neverland',
#  'The Last of the Mohicans': 'Glory',
#  'Scary Movie 3': 'The Usual Suspects',
#  'The Fugitive': 'Live Nude Girls Unite!',
#  'The Truman Show': 'Apocalypse Now',
#  'Inu-Yasha: The Movie 2: The Castle Beyond the Looking Glass': 'Gundam Wing: The Movie: Endless Waltz',
#  'The Bourne Supremacy': 'Heaven',
#  'Gothika': 'Regarding Henry',
#  'Spellbound': 'Vietnam: A Television History',
#  "The General's Daughter": 'Hard to Kill',
#  'Kinsey': 'Tinker, Tailor, Soldier, Spy',
#  'The Patriot': 'Jingle All the Way',
#  'Ace Ventura: When Nature Calls': 'Beauty Shop',
#  'Blood Simple': 'Contact',
#  'In & Out': 'The Life Aquatic with Steve Zissou',
#  'Gone in 60 Seconds': 'Office Space',
#  'The Rock': 'Monster',
#  '2001: A Space Odyssey': 'Mon Oncle',
#  'Green Card': 'The Sixth Sense',
#  'The Night Stalker / The Night Strangler': 'Out for Justice',
#  'Wild Wild West': 'Tremors 4: The Legend Begins',
#  'Housesitter': 'The Wedding Planner',
#  'Black Sheep': 'Screamers',
#  'Sweet Home Alabama': 'Absolutely Fabulous: Series 2',
#  'Army of Darkness': 'Richard III',
#  'Swimming Pool': 'Marathon Man',
#  'Forrest Gump': 'Internal Affairs',
#  'The Simpsons: Treehouse of Horror': 'Xena: Warrior Princess: Season 3',
#  'The Mask of Zorro': 'Clash of the Titans',
#  'Captain Ron': 'Princess Mononoke',
#  'The Best of Friends: Season 1': 'Star Trek: Voyager: Season 1',
#  'The Pianist': 'Buffy the Vampire Slayer: Season 6',
#  'Homeward Bound: The Incredible Journey': 'American Beauty',
#  'Searching for Bobby Fischer': 'The Manchurian Candidate',
#  'Everest: The Death Zone': 'Pay It Forward',
#  'The Italian Job': 'Frailty',
#  'Citizen Kane': 'The Color of Money',
#  'The Evil Dead': 'Lucio Fulci: The Beyond',
#  'The Full Monty': 'The Lord of the Rings: The Fellowship of the Ring: Extended Edition',
#  'Scary Movie 2': 'American History X',
#  'Air Force One': 'Tenchi the Movie: Tenchi Muyo! In Love',
#  'Star Wars: Episode V: The Empire Strikes Back': 'Queer as Folk: Season 2',
#  'Always': 'The Running Man',
#  'Napoleon Dynamite': 'Apollo 13',
#  'Shall We Dance?': 'Identity',
#  'Pirates of the Caribbean: The Curse of the Black Pearl': 'Parenthood',
#  'Futurama: Vol. 1': 'BASEketball',
#  'Secret Window': 'Stuart Little 2',
#  'Mystic River': 'Jane Eyre',
#  'Raiders of the Lost Ark': 'A Little Princess',
#  'The Princess Bride': 'Titanic',
#  'Speed': 'Apocalypse Now Redux',
#  'Collateral Damage': 'The Sopranos: Season 4',
#  'Sky Captain and the World of Tomorrow': 'Pearl Harbor',
#  'Dirty Harry': "Pink Floyd: Live at Pompeii: Director's Cut",
#  'Notting Hill': 'L.A. Story',
#  'Patch Adams': 'The Great Outdoors',
#  'Terms of Endearment': 'Jimmy Neutron: Boy Genius',
#  'About a Boy': 'Pay It Forward',
#  'National Treasure': 'The Best of Friends: Season 2',
#  'The Waterboy': "ABC Primetime: Mel Gibson's The Passion of the Christ",
#  'Joan of Arc': 'The Limey',
#  "Bram Stoker's Dracula": '28 Days',
#  'Hollow Man': 'Broken Arrow',
#  '54': 'Hero',
#  'Nurse Betty': 'The Hand that Rocks the Cradle',
#  'Absolute Power': 'The Matrix',
#  'Critical Condition': 'Cousins',
#  'The Recruit': 'Ever After: A Cinderella Story',
#  'Cats & Dogs': 'Saving Private Ryan',
#  'Tomb Raider': 'Liberty Stands Still',
#  'American History X': 'Star Trek: Voyager: Season 5',
#  'Romancing the Stone': 'Bottle Rocket',
#  'Black Adder IV': 'Pride and Prejudice',
#  'Men of Honor': 'Good Morning, Vietnam',
#  'A League of Their Own': 'Jimmy Neutron: Boy Genius',
#  'Along Came a Spider': 'Dangerous Minds',
#  'The Remains of the Day': 'Waking Ned Devine',
#  'Love Potion #9': 'Groundhog Day',
#  'Married... with Children: The Most Outrageous Episodes: Vol. 1': 'The Best of Friends: Vol. 4',
#  'The Royal Tenenbaums': 'Police Academy 3: Back in Training',
#  'Demolition Man': 'Sabrina',
#  'Pushing Tin': 'Natural Born Killers',
#  'Of Mice And Men': 'Dodgeball: A True Underdog Story',
#  'What Lies Beneath': 'American Splendor',
#  'Me, Myself & Irene': 'Spartan',
#  'Sideways': 'Secretary',
#  "One Flew Over the Cuckoo's Nest": 'Ella Enchanted',
#  'Broken Arrow': 'The Mirror Has Two Faces',
#  'The Dresser': 'Black Orpheus',
#  'Spider-Man 2': 'The Hurricane',
#  'Hero': 'The Man Who Cried',
#  'Swordsman 2': 'Rurouni Kenshin',
#  'Barton Fink': 'Billy Madison',
#  'Lawrence of Arabia': 'Wallace & Gromit in Three Amazing Adventures',
#  'Pet Sematary': '48 Hrs.',
#  'Bottle Rocket': 'Braveheart',
#  'The Birds': 'The Twilight Zone: Vol. 12',
#  'The Yes Men': 'Bad Education',
#  'Midnight Cowboy': 'Thin Man Collection: Alias Nick and Nora',
#  'The Peacemaker': 'Nighthawks',
#  'A Few Good Men': 'The Watcher',
#  "Monty Python's And Now for Something Completely Different": 'Rocky',
#  'Top Gun': 'The Love Letter',
#  'He Loves Me, He Loves Me Not': 'Strange Brew',
#  'Police Academy: Special Edition': 'Stir Crazy',
#  'Nosferatu: Original Version': 'Buffy the Vampire Slayer: Season 7',
#  'Batman & Robin': 'The X-Files: Fight the Future',
#  'Lord of the Rings: The Two Towers: Extended Edition': 'The People vs. Larry Flynt',
#  'Breathless': "Something's Gotta Give",
#  'Like Water for Chocolate': 'Lock, Stock and Two Smoking Barrels',
#  'Battle Athletes Victory: Vol. 7: The Last Dance': 'Gladiator',
#  'Cirque du Soleil: Quidam': "A Midsummer Night's Dream",
#  'Hardball': "National Lampoon's Vacation",
#  'Best in Show': 'Dead Man Walking',
#  'Secondhand Lions': 'The Godfather',
#  'Druids': 'Congo',
#  'Bullets Over Broadway': 'Party Monster',
#  'Batman': 'Mansfield Park',
#  'Eraser': 'Screamers',
#  'Short Circuit': 'Hudson Hawk',
#  'The Sopranos: Season 1': 'The Best of Friends: Season 2',
#  'Manhattan': 'Treasure Planet',
#  'Mission: Impossible': 'Beverly Hills Cop III',
#  'The Whole Nine Yards': 'Into the Woods',
#  'Good Burger': 'I, Robot',
#  'A Clockwork Orange': 'Star Trek: The Motion Picture',
#  'GoldenEye': 'Jurassic Park',
#  'Star Trek: The Original Series: Vols. 1-15': 'House of the Dead',
#  'The Fifth Element': 'Bean: The Movie',
#  'Bad Santa': 'Bound',
#  'The Grapes of Wrath': 'O Brother, Where Art Thou?',
#  'Runaway Jury': 'Fight Club: Bonus Material',
#  'Solaris': 'Life as a House',
#  'Mercury Rising': "ABC Primetime: Mel Gibson's The Passion of the Christ",
#  'On the Town': 'Super Size Me',
#  'Into the Arms of Strangers: Stories of the Kindertransport': 'The Fog of War',
#  'Knockaround Guys': 'Robin Williams: Live on Broadway',
#  'Cocoon': "Trainspotting: Collector's Edition",
#  'Star Trek: First Contact': 'Band of Brothers',
#  'Moonstruck': 'Fifteen Minutes',
#  'Coming Home': 'Bowling for Columbine',
#  'Raising Arizona': "Muriel's Wedding",
#  'Field of Dreams': 'Xena: Warrior Princess: Season 3',
#  'Frogs': 'The Song of Bernadette',
#  'American Pie': 'Absolutely Fabulous: Series 5',
#  'Shadowlands': "Predator: Collector's Edition",
#  'The Simpsons: Season 4': 'Two Brothers',
#  'The Sopranos: Season 4': 'Touching the Void',
#  'Erin Brockovich': 'PCU',
#  'Protocol': 'Jaws',
#  'Palmetto': 'The Great Race',
#  'Die Hard With a Vengeance': 'Dr. Strangelove',
#  'Snake Eyes': 'First Knight',
#  'White Chicks': "Wayne's World",
#  'American Pie 2': "Footloose: Special Collector's Edition",
#  "Salem's Lot": 'Elf',
#  'The Hunt for Red October': 'The Last Temptation of Christ',
#  'Identity': 'Lock, Stock and Two Smoking Barrels',
#  'Big Night': 'Soul Food: Season 1',
#  'Black Hawk Down': 'The Simpsons: Season 1',
#  'Halloween': 'The Twilight Zone: Vol. 15',
#  'Victim': '11:14',
#  'Spy Game': "Charlotte's Web",
#  'Awakenings': 'I Love Lucy: Season 2',
#  'White Noise': 'The Magdalene Sisters',
#  'Hellraiser IV: Bloodline': 'Sordid Lives',
#  'The X-Files: Fight the Future': 'Glory',
#  'Confessions of a Dangerous Mind': 'As Good as It Gets',
#  'Trading Places': 'Reno 911: Season 2',
#  'The Bone Collector': 'Patriot Games',
#  'The Phantom of the Opera': 'The Witches of Eastwick',
#  'Opera': 'Richard III',
#  'Men in Black II': 'Rose Red',
#  'Lethal Weapon 4': 'The Producers',
#  'Head Over Heels': 'Eloise at the Plaza',
#  'Down by Law': 'WMD: Weapons of Mass Deception',
#  'Frequency': 'The Pacifier',
#  'The Maltese Falcon': 'Gandhi',
#  'Little Shop of Horrors': 'Xena: Warrior Princess: Season 3',
#  'The Matrix: Reloaded': 'Once Were Warriors',
#  'Freeway': 'Starman',
#  'Tears of the Sun': 'Party of Five: Season 1',
#  'Kiss the Girls': 'Ghosts of Rwanda: Frontline',
#  'Traffic': 'The Score',
#  'The Wedding Planner': 'A Walk to Remember',
#  'Miss Congeniality': 'Legally Blonde',
#  'From Russia With Love': 'X2: X-Men United',
#  'Sleeping Beauty: Special Edition': 'The Last Samurai',
#  'Fahrenheit 451': 'A.I. Artificial Intelligence',
#  'Girl, Interrupted': 'Children of the Corn',
#  'The Princess Diaries (Widescreen)': 'Wallace & Gromit in Three Amazing Adventures',
#  'The Ring': 'The Cowboys',
#  'Entrapment': 'To Catch a Thief',
#  'Rambling Rose': 'Life as a House',
#  'Superman II': 'O Brother, Where Art Thou?',
#  'Bridget Jones: The Edge of Reason': 'The Warriors',
#  'Lynyrd Skynyrd: Lyve from Steel Town': 'The Twilight Zone: Vol. 39',
#  'The Last Waltz': 'Super Size Me',
#  'Oh God!': 'Jimmy Neutron: Boy Genius',
#  'What Women Want': 'The Simple Life: Season 1',
#  'Jurassic Park III': 'Rob Roy',
#  'Best of The Muppet Show: George Burns / Bob Hope / Dom DeLuise': 'Touched by an Angel: Season 1',
#  'Papillon': 'Star Trek: The Next Generation: Season 7',
#  'Boogeyman': 'The Usual Suspects',
#  'Men in Black': "The Devil's Own",
#  'Fight Club': 'Roughnecks: The Starship Troopers Chronicles: The Pluto Campaign',
#  'Chocolat': 'Spartan',
#  'Dead Alive': 'Beauty Shop',
#  'Judgment at Nuremberg': 'Star Trek: Deep Space Nine: Season 1',
#  'Dragon Ball: The Saga of Goku': 'Gundam Wing: The Movie: Endless Waltz',
#  'Point Break': 'Caddyshack',
#  'The Dirty Dozen': 'Raw',
#  'Holes': 'The Quiet American',
#  'Star Wars: Episode IV: A New Hope': 'Friends: Season 6',
#  'Taboo: Season 1': 'Silkwood',
#  '13 Going on 30': 'As Good as It Gets',
#  'The Matchmaker': 'Scream',
#  'Swordfish': 'CSI: Season 1',
#  'Hannibal': 'The Hunt for Red October',
#  'Highlander': 'Tommy Boy',
#  'Saving Silverman': 'Final Fantasy: The Spirits Within',
#  'The Faculty': 'Of Unknown Origin',
#  'The Rainmaker': 'Gone in 60 Seconds',
#  'Love Comes Softly': "Something's Gotta Give",
#  'Singles': 'The Commitments',
#  'A Nightmare on Elm Street 3: Dream Warriors': 'Robin Hood: Prince of Thieves',
#  'Mean Girls': 'Sick',
#  'L.A. Confidential': 'Evolution',
#  'The Phantom of the Opera: Special Edition': 'Lord of the Rings: The Return of the King',
#  'Blind Date': 'Firestarter',
#  'Milk Money': 'A Little Princess',
#  'The French Connection': 'Caddyshack',
#  'Entourage: Season 1': 'Six Feet Under: Season 4',
#  'The Package': 'Reservoir Dogs',
#  'Armageddon': 'Miracle on 34th Street',
#  'Futurama: Vol. 2': "One Flew Over the Cuckoo's Nest",
#  'We Were Soldiers': 'Strange Brew',
#  'Con Air': 'Kurogane Communication: Memories of Earth',
#  'Pulp Fiction': 'A Bridge Too Far',
#  'The Right Stuff': 'Down and Out in Beverly Hills',
#  "The Powerpuff Girls: Down 'n' Dirty": "That '70s Show: Season 1",
#  'Crossroads': 'Justice League',
#  'Underworld': 'The Godfather, Part III',
#  'Wag the Dog': 'The Game',
#  'The Breakfast Club': 'Gone in 60 Seconds',
#  'Of Mice and Men': 'Being John Malkovich',
#  'Mafia!': 'The King of Queens: Season 2',
#  'The Last Starfighter': 'Men in Black II',
#  'Lord of the Rings: The Return of the King': 'Glory: Bonus Material',
#  'Alice in Wonderland': 'The Adventures of Pete & Pete: Season 1',
#  'How to Lose a Guy in 10 Days': 'In the Name of the Father',
#  'The Family Man': 'Paycheck',
#  'The Great Dictator': 'American Beauty',
#  'Austin Powers: The Spy Who Shagged Me': 'City Lights',
#  'Turtles Can Fly': 'To Kill a Mockingbird',
#  'Vanilla Sky': 'Batman Begins',
#  "The Butcher's Wife": 'High Fidelity',
#  'On the Edge': 'Scream 3',
#  'Michael': 'Aladdin: Platinum Edition',
#  'The Sixth Sense': "It's a Wonderful Life",
#  'Lost in Translation': 'Men in Black',
#  'Scream': 'Pride and Prejudice',
#  'The Outsiders': 'Ride with the Devil',
#  'How Stella Got Her Groove Back': "Schindler's List",
#  'Outbreak': 'Party Monster',
#  'High Roller: The Stu Ungar Story': "Miller's Crossing",
#  'Nine to Five': 'Party Monster',
#  'Blade': 'Spanglish',
#  'Bruce Almighty': 'Silkwood',
#  'Ransom': 'Forrest Gump',
#  'The Ninth Gate': 'Toy Story',
#  'I, Robot': 'Futurama: Monster Robot Maniac Fun Collection',
#  'The Magnificent Seven': 'Reservoir Dogs',
#  'The Sword in the Stone': 'The Pledge',
#  'Monty Python and the Holy Grail': 'Celebrity',
#  'Fiddler on the Roof': 'Almost Famous',
#  'The Player': '8 1/2',
#  'Young Guns': 'All Quiet on the Western Front',
#  'Minority Report': 'The Brothers McMullen',
#  'Buffy the Vampire Slayer: Season 6': 'Harold and Kumar Go to White Castle',
#  'Clash of the Titans': 'Rabbit-Proof Fence',
#  'Beverly Hills Cop III': 'The Last Seduction',
#  'Lord of the Rings: The Two Towers': 'The Lion King: Special Edition',
#  'Blue Crush': 'Dr. Quinn, Medicine Woman: Season 2',
#  'The Village': 'History of the World: Part 1',
#  'Whale Rider': 'Amelie',
#  'Steel Magnolias': 'Sister Act 2: Back in the Habit',
#  'Platoon': 'Good Will Hunting',
#  "Gone with the Wind: Collector's Edition": 'Party Monster',
#  'The First Power': 'Hellbound: Hellraiser II',
#  'The Lost Boys: Special Edition': 'Irreversible',
#  'Arabian Nights': 'Beauty Shop',
#  'Chicken Run': 'Mansfield Park',
#  'Working Girl': 'Superman: The Movie',
#  'House of Sand and Fog': 'Starman',
#  'Anger Management': 'Out of Africa',
#  'Happy Gilmore': 'Goldfinger',
#  'Legend of the Dragon Kings: Red Dragon': 'Blue Seed: Beyond',
#  "Ocean's Eleven": 'A Man Apart',
#  'Dogma': 'Moonstruck',
#  'Light Keeps Me Company': 'Wild Strawberries',
#  'Under the Tuscan Sun': 'Y Tu Mama Tambien',
#  'Sin City': 'Meet Me in St. Louis',
#  'The Exorcist': 'Kill Bill: Vol. 2',
#  'Deliverance': 'The Third Miracle',
#  'Beverly Hills Cop': "Predator: Collector's Edition",
#  'Driving Miss Daisy': 'Tremors 4: The Legend Begins',
#  'The Negotiator': 'Snatch',
#  'The Pelican Brief': 'Mississippi Burning',
#  'South Park: Bigger, Longer and Uncut': 'What the #$*! Do We Know!?',
#  'Tomorrow Never Dies': 'South Park: Bigger, Longer and Uncut',
#  'Independence Day': 'Lord Peter Wimsey: Murder Must Advertise',
#  'Magnolia': 'Futurama: Vol. 1',
#  'Birth': 'Little House on the Prairie: Season 2',
#  "Alien 3: Collector's Edition": 'Don Juan De Marco',
#  'Rising Sun': 'Ed Wood',
#  'Team America: World Police': 'Dr. Strangelove',
#  'Universal Soldier': 'Casino: 10th Anniversary Edition',
#  'Taxi Driver': 'Indiana Jones and the Last Crusade',
#  'Cabin Fever': '28 Days Later',
#  'The Edge': 'Stargate SG-1: Season 7',
#  '24: Season 3': 'Midnight Cowboy',
#  'Collateral': 'About Schmidt',
#  'Carolina': 'Pride and Prejudice',
#  'The Godfather, Part II': 'Giant',
#  'Kung Pow: Enter the Fist': 'Pay It Forward',
#  'It Was a Wonderful Life': 'Seven',
#  "A Nightmare on Elm Street 2: Freddy's Revenge": 'Police Academy 4: Citizens on Patrol',
#  'The Winslow Boy': 'Kill Bill: Vol. 2',
#  'Ghost World': 'Once Upon a Time in the West',
#  'Romeo Must Die': 'Donnie Darko',
#  'A Perfect Murder': 'Beetlejuice',
#  'The Untouchables': 'Citizen Kane',
#  'X-Men': 'Curly Sue',
#  "Sharpe 10: Sharpe's Siege": 'Radio',
#  'The Firm': 'A Life Less Ordinary',
#  'Be Cool': 'Like Water for Chocolate',
#  'Scrubs: Season 1': 'The Deer Hunter',
#  'Pay It Forward': 'Monsoon Wedding',
#  "Ferris Bueller's Day Off": "Alien: Collector's Edition",
#  'The Avengers': 'Sunshine',
#  'The Witches of Eastwick': 'Who Framed Roger Rabbit?: Special Edition',
#  'Million Dollar Baby': '8 1/2',
#  'The Crush': 'Lewis Black: Black on Broadway',
#  'Cool Runnings': 'Scrooged',
#  'Cruel Intentions': 'Pride and Prejudice',
#  'Big Fat Liar': 'Left Behind II: Tribulation Force',
#  'Sliding Doors': 'A Fish Called Wanda',
#  'Running Mates': 'Jade',
#  'The Great Outdoors': 'Beauty Shop',
#  'The Great Escape': 'Ed Wood',
#  'Armed and Dangerous': 'Classic Cartoon Favorites: Starring Donald',
#  'The Love Bug': 'Pay It Forward',
#  'The Apartment': 'Polyester',
#  'The Eye': 'Ray',
#  'Bringing Out the Dead': 'Sideways',
#  'Rain Man': 'Big Fish',
#  'The Notebook': 'Hard Boiled',
#  'E.T. the Extra-Terrestrial: The 20th Anniversary (Rerelease)': "Gone with the Wind: Collector's Edition",
#  'Shallow Grave': 'Sexy Beast',
#  'The Dick Van Dyke Show: Season 5': 'Alias: Season 1',
#  'The Cutting Edge': "Alien: Collector's Edition",
#  "Who's Your Daddy": 'The Godfather',
#  'X2: X-Men United': 'Igby Goes Down',
#  'When Harry Met Sally': 'Cold Mountain',
#  'Sabrina': 'Dangerous Minds',
#  'Kindergarten Cop': 'Mansfield Park',
#  'Highlander 2: Renegade Version': 'The Indiana Jones Trilogy: Bonus Material',
#  'Ali': 'Fahrenheit 9/11',
#  'Crouching Tiger, Hidden Dragon': 'Ossessione',
#  'Blade 2': 'The First Wives Club',
#  'The Mummy': 'Benny and Joon',
#  'Lethal Weapon': 'Spitfire Grill',
#  'The Hunchback of Notre Dame': 'Old School',
#  'GoodFellas: Special Edition': 'Raiders of the Lost Ark',
#  'The Scarlet Letter': 'Evolution',
#  'Ghost Ship': 'Screamers',
#  'Pleasantville': 'Serial Mom',
#  'Bed of Roses': 'Under Siege',
#  'Envy': 'Sex and the City: Season 4',
#  'Desperado / El Mariachi': 'Hellbound: Hellraiser II',
#  'Stuck on You': 'Jason and the Argonauts',
#  'Mona Lisa': 'Ghost Dog: The Way of the Samurai',
#  'Simpsons Gone Wild': 'Woman of the Year',
#  'K-Pax': 'Star Trek: The Next Generation: Season 7',
#  "White Men Can't Jump": 'Four Weddings and a Funeral',
#  'The Twilight Zone: Vol. 3': 'The X-Files: Season 9',
#  'Jaws': 'Absolute Power',
#  'Goldfinger': "Mackenna's Gold",
#  'Ghost': 'South Park: Passion of the Jew',
#  'Bananas': 'Hellbound: Hellraiser II',
#  'L.A. Story': 'The Man Who Knew Too Little',
#  'Troy': 'The Bridge on the River Kwai',
#  'Psycho': 'Star Trek: The Motion Picture',
#  'Willow': 'Seven Samurai',
#  'Six Feet Under: Season 2': 'Best of The Muppet Show: Peter Sellers / John Cleese / Dudley Moore',
#  'Stir of Echoes': 'Freddy vs. Jason',
#  'Real Women Have Curves': 'The Hand that Rocks the Cradle',
#  'RoboCop': 'Notorious C.H.O.',
#  'Bull Durham': 'Jack',
#  "The Butterfly Effect: Director's Cut": 'Aqua Teen Hunger Force: Vol. 1',
#  "The Go-Go's: Live in Central Park": 'Classic Albums: Meat Loaf: Bat Out of Hell',
#  'Matchstick Men': 'The Green Mile',
#  'Meet the Parents': 'The Mighty',
#  'Ferngully: The Last Rainforest': 'Spitfire Grill',
#  'The Adventures of Robin Hood': 'Wiseguy: Prey for the City',
#  'Family Guy: Vol. 1: Seasons 1-2': 'Infernal Affairs III',
#  'Rush Hour': 'The Thomas Crown Affair',
#  'Maverick': 'Office Space',
#  'Big Bully': 'The Good, the Bad and the Ugly',
#  'Adaptation': 'Serendipity',
#  'The Bounty': 'Gandhi',
#  'Inspector Morse 25: Cherubim & Seraphim': 'What the #$*! Do We Know!?',
#  'Dragnet': 'The Last Temptation of Christ',
#  'Johnson Family Vacation': 'Armageddon',
#  'Miracle on 34th Street': 'Braveheart',
#  "Muriel's Wedding": 'Ed Wood',
#  'Firestarter': 'Lilo and Stitch',
#  'Lilo and Stitch': 'The Simpsons: Treehouse of Horror',
#  'Xena: Warrior Princess: Season 3': 'The Pacifier',
#  'The Pacifier': 'Fallen',
#  'Fallen': 'Garden State',
#  'Garden State': 'Total Recall',
#  'Total Recall': 'Mystic River',
#  'Jane Eyre': 'Glory',
#  'Glory': 'Mutiny on the Bounty',
#  'Mutiny on the Bounty': 'The Mummy',
#  'Benny and Joon': 'Mystic Pizza',
#  'Mystic Pizza': 'A Walk to Remember',
#  'A Walk to Remember': 'I Love Lucy: Season 5',
#  'I Love Lucy: Season 5': 'Ninotchka',
#  'Ninotchka': 'Donnie Darko',
#  'Donnie Darko': 'Patch Adams',
#  'Beauty Shop': 'Herbie Rides Again',
#  'Herbie Rides Again': 'Sex and the City: Season 4',
#  'Sex and the City: Season 4': 'Fire in the Sky',
#  'Fire in the Sky': 'Ray',
#  'Ray': 'Band of Brothers',
#  'Band of Brothers': 'Enemy at the Gates',
#  'Enemy at the Gates': 'Almost Famous',
#  'Almost Famous': 'Black Adder',
#  'Black Adder': 'Reservoir Dogs',
#  'Reservoir Dogs': 'Talk to Her',
#  'Talk to Her': 'Memento',
#  'Memento': 'The Secret of My Success',
#  'The Secret of My Success': 'Bend It Like Beckham',
#  'Bend It Like Beckham': 'Lethal Weapon',
#  'Spitfire Grill': 'Silkwood',
#  'Silkwood': 'Rush Hour 2',
#  'Rush Hour 2': 'GoodFellas: Special Edition',
#  'A Little Princess': 'North by Northwest',
#  'North by Northwest': 'Pay It Forward',
#  'Monsoon Wedding': 'The Deer Hunter',
#  'The Deer Hunter': 'The Pledge',
#  'The Pledge': 'X2: X-Men United',
#  'Bulletproof Monk': 'The Matrix: Revolutions',
#  'I Am Sam': "Antonia's Line",
#  'Alex and Emma': 'Taxi Driver',
#  'Girlfight': 'A Beautiful Mind',
#  'Rambo: First Blood: Ultimate Edition': 'Harold and Kumar Go to White Castle',
#  'Rocky IV': 'The 4400: Season 1',
#  'The Age of Innocence': "That '70s Show: Season 1",
#  "National Lampoon's European Vacation": 'Free Willy',
#  "Lemony Snicket's A Series of Unfortunate Events": 'John Q',
#  'Unbreakable': 'A Cinderella Story',
#  'The Juror': 'The Recruit',
#  'Road to Perdition': 'From Hell',
#  'Back to the Future': 'The Pianist',
#  'Bowling for Columbine': 'Open Range',
#  'Jesus of Nazareth': 'Wild at Heart',
#  'Vision Quest': 'The Matrix: Revolutions',
#  "Breakin' All the Rules": 'Friends: Season 2',
#  'Dodgeball: A True Underdog Story': 'Selena',
#  'The Rosa Parks Story': 'The Game',
#  'Beyond Borders': '12 Monkeys',
#  'Born on the Fourth of July': 'Happiness',
#  'Return to Me': 'The Talented Mr. Ripley',
#  'Gangs of New York': 'Dr. Strangelove',
#  'The Client': 'Immortal Beloved',
#  "National Lampoon's Vacation": 'Say Anything',
#  'Star Wars: Episode II: Attack of the Clones': 'Friday After Next',
#  '13 Conversations About One Thing': 'Garden State',
#  'Runaway Bride': 'The West Wing: Season 1',
#  'The School of Rock': 'Roxanne',
#  'Ice Age': 'Firestarter',
#  'Titanic': 'Hocus Pocus',
#  'With Six You Get Eggroll': 'The Twilight Zone: Vol. 15',
#  'Family Guy: Vol. 2: Season 3': 'We Were Soldiers',
#  'Buffy the Vampire Slayer: Season 5': 'Wild Things',
#  'Final Destination': 'Free Willy',
#  'Dead Man Walking': 'Dragon: The Bruce Lee Story',
#  'Murder By Numbers': 'Taxi Driver',
#  'The Last Emperor': 'The Simpsons: Season 3',
#  'Love Actually': 'The Bourne Identity',
#  'Van Helsing': 'In Living Color: Season 2',
#  'The Exorcist: Restored Version': 'In the Heat of the Night',
#  'Saw': 'Signs',
#  'Grande Ecole': 'All in the Family: Season 3',
#  'The Bridges of Madison County': 'The Breakfast Club',
#  'The Haunted Mansion': 'I Love Lucy: Season 4',
#  'Heavenly Creatures': "The Devil's Brigade",
#  'Terminator 3: Rise of the Machines': 'The Italian Job',
#  'The Terminal': 'American History X',
#  'The Great St. Louis Bank Robbery': 'The Taking of Pelham One Two Three',
#  'The Hurricane': 'Race the Sun',
#  'A Touch of Class': 'Monarch of the Glen: Series 2',
#  'Mad Max': 'The Shining',
#  'To Catch a Thief': 'Slayers DVD Collection',
#  'Good Will Hunting': 'A River Runs Through It',
#  'Gladiator': 'Peter Gabriel: Growing Up Live',
#  "Logan's Run": 'Threesome',
#  'In Good Company': 'Cinderella: Special Edition',
#  'Easy Rider': 'Fight Club',
#  'The Matrix': 'Thunderbolt and Lightfoot',
#  'Jurassic Park': 'Starsky & Hutch',
#  'My Big Fat Greek Wedding': 'Where the Heart Is',
#  'Caddyshack': 'Yu Yu Hakusho',
#  'As Good as It Gets': 'Braveheart',
#  'The Princess Diaries (Fullscreen)': 'Beverly Hills Cop III',
#  'The Accused': 'MASH: Season 7',
#  'Retroactive': 'Gettysburg',
#  'Waiting for Guffman': 'Philadelphia',
#  'Chicago': 'The Carol Burnett Show: Show Stoppers',
#  'I Still Know What You Did Last Summer': 'The Deer Hunter',
#  'Monarch of the Glen: Series 1': 'The Vicar of Dibley: Series 2 and Specials',
#  'Cool Hand Luke': 'Eric Clapton Unplugged',
#  'Risky Business': 'Blade Runner',
#  'Anywhere But Here': 'Reservoir Dogs',
#  'Father of the Bride': 'Disclosure',
#  'Cast Away': 'Seven Years in Tibet',
#  'John Q': 'The Machinist',
#  'Sleeping With the Enemy': 'Smokey and the Bandit Part 3',
#  'Sister Act': 'Scent of a Woman',
#  'Good Morning, Vietnam': 'Star Wars: Episode II: Attack of the Clones',
#  'Blazing Saddles': 'Rounders',
#  'Antwone Fisher': "Devil's Playground",
#  "America's Sweethearts": "Michael Moore's The Awful Truth: Season 2",
#  'Sister Act 2: Back in the Habit': 'Touched by an Angel: Season 1',
#  'The Twilight Zone: Vol. 22': 'Roswell: Season 2',
#  'Planet of the Apes': 'Any Given Sunday',
#  'Arrested Development: Season 2': 'Reservoir Dogs',
#  'In Too Deep': 'The Hunchback of Notre Dame II',
#  'A Time to Kill': 'Millennium Actress',
#  'Dances With Wolves: Special Edition': 'The Flintstones: Season 2',
#  'Extremities': 'House of Sand and Fog',
#  'The 13th Warrior': 'Stargate SG-1: Season 7',
#  'Heaven Can Wait': 'The Silence of the Lambs',
#  'Tetsuo: The Iron Man': 'Chris Rock: Never Scared',
#  "All the President's Men": 'Star Trek: Enterprise: Season 1',
#  'Rocky': 'Lord of the Rings: The Return of the King',
#  "Jason's Lyric": 'Dogma',
#  'Wolfen': 'The Deer Hunter',
#  'Daydream Obsession': 'Radio',
#  'Monster': 'The Mask of Zorro',
#  'Bird on a Wire': 'Rear Window',
#  'Finding Nemo (Widescreen)': 'Billy Madison',
#  'Intolerable Cruelty': 'The Bicycle Thief',
#  'The Birdcage': 'The Rundown',
#  'The Anarchist Cookbook': 'The Silence of the Lambs',
#  'Giant': 'Wallace & Gromit in Three Amazing Adventures',
#  'Seabiscuit': 'Men of Honor',
#  'Kramer vs. Kramer': 'Walking Tall',
#  'The Thomas Crown Affair': 'Viva La Bam: Season 1',
#  'Dragon Ball Z: Cell Games': 'Rurouni Kenshin',
#  'Son of the Mask': 'Hitch',
#  'G.I. Jane': 'Lord of the Rings: The Two Towers: Extended Edition',
#  'Star Trek V: The Final Frontier': 'Italian for Beginners',
#  'My Dog Skip': 'Firestarter',
#  'Hidalgo': 'Domestic Disturbance',
#  "Harry Potter and the Sorcerer's Stone": 'Final Destination 2',
#  'Twister': 'Mystery, Alaska',
#  'A Beautiful Mind': "The Wizard of Oz: Collector's Edition",
#  'Hamlet': 'The Godfather, Part II',
#  'Panic Room': 'Best in Show',
#  "St. Elmo's Fire": 'Die Hard 2: Die Harder',
#  'The Simpsons: Season 6': 'Heat: Special Edition',
#  "My Best Friend's Wedding": 'Spirited Away',
#  "Von Ryan's Express": 'The In-Laws',
#  'Indiana Jones and the Temple of Doom': 'Ride with the Devil',
#  'Rooster Cogburn': 'Most Wanted',
#  'Sex and the City: Season 1': 'Seeta Aur Geeta',
#  'The X-Files: Season 5': 'Fire in the Sky',
#  "Maria's Lovers": 'Pearl Harbor',
#  'Wonder Boys': 'Mannequin',
#  'Popeye': 'Comedian',
#  "Dr. Seuss' The Cat in the Hat": 'Amelie',
#  "Footloose: Special Collector's Edition": 'The Bad and the Beautiful',
#  'Upstairs, Downstairs: Season 1': 'Alias: Season 3',
#  'Bring It On': 'The Looney Tunes Golden Collection: Vol. 1',
#  'Day of the Dead': 'When Harry Met Sally',
#  'The Return of Ruben Blades': 'Lawrence of Arabia',
#  'Blade Runner': 'Willow',
#  'Double Jeopardy': 'Super Size Me',
#  "Charlotte's Web": 'The Cider House Rules',
#  'The Manchurian Candidate': "That '70s Show: Season 1",
#  'Emma': 'Liar Liar',
#  'Record of Lodoss War: Chronicles of the Heroic Knight': "Extreme Engineering: Tokyo's Sky City",
#  'Regarding Henry': 'Funny Face',
#  'George Washington': 'Finding Neverland',
#  'Shiloh': 'Pokemon 3: The Movie',
#  'The Shawshank Redemption: Special Edition': 'Where Eagles Dare',
#  "Schindler's List": "Mr. Holland's Opus",
#  'Eternal Sunshine of the Spotless Mind': 'Rain Man',
#  'The Terminator': 'The Graduate',
#  '3000 Miles to Graceland': 'Back to the Future Part III',
#  'Legally Blonde 2: Red, White & Blonde': 'Monsoon Wedding',
#  'Lord of the Rings: The Return of the King: Extended Edition': 'Scarface: 20th Anniversary Edition',
#  'The Art of War': 'Star Trek: Deep Space Nine: Season 5',
#  'West Side Story': 'Finding Nemo (Widescreen)',
#  'The King of Comedy': 'A Night at the Opera',
#  'The Twilight Zone: Vol. 38': 'Absolutely Fabulous: Series 5',
#  'Silver Streak': 'Simple Men',
#  'Austin Powers: International Man of Mystery': 'The Flintstones in Viva Rock Vegas',
#  'Chaos': 'Reservoir Dogs',
#  'Henry V': 'Richard III',
#  'The Fighting Temptations': 'The Secret Garden',
#  'Super Size Me': 'Dirty Dancing',
#  'Tango & Cash': 'Girl, Interrupted',
#  'Six Feet Under: Season 4': 'Bringing Up Baby',
#  'Stigmata': 'Saturday Night Live: The Best of Will Ferrell 2',
#  'Tombstone': 'Kill Bill: Vol. 2',
#  'Andre': 'E.T. the Extra-Terrestrial: The 20th Anniversary (Rerelease)',
#  'The Nutty Professor II: The Klumps': 'Grumpier Old Men',
#  'Dragon Ball Z: Trunks Saga': 'Gungrave',
#  'Snatch': 'Farscape: Season 2',
#  'Big Fish': "The Crying Game: Collector's Edition",
#  'Ruthless People': 'Groundhog Day',
#  'Mister Roberts': 'Reservoir Dogs',
#  'Dazed and Confused': 'The American President',
#  'Bad Boys II': 'Kill Bill: Vol. 1',
#  'Led Zeppelin: The Song Remains the Same': 'Doctor Who: The Talons of Weng-Chiang',
#  'Eight Men Out': "ABC Primetime: Mel Gibson's The Passion of the Christ",
#  'Evolution': 'Aladdin: Platinum Edition',
#  'Lethal Weapon 2': 'The Tuxedo',
#  'The Wedding Singer': 'Best in Show',
#  'Anaconda': 'Rob Roy',
#  'The Rescuers Down Under': "Monty Python's The Meaning of Life: Special Edition",
#  "Brian's Song": 'Y Tu Mama Tambien',
#  'On the Waterfront': 'Band of Brothers',
#  'The Fabulous Baker Boys': 'Life as a House',
#  'Austin Powers in Goldmember': 'Alias: Season 1',
#  'The Motorcycle Diaries': 'Dogma',
#  'An American Werewolf in Paris': 'American Psycho',
#  'Dead Poets Society': "What's Eating Gilbert Grape",
#  'Baby Boom': 'D.A.R.Y.L.',
#  'True Romance': 'Absolutely Fabulous: Series 5',
#  'Gay Weddings': 'The Deer Hunter',
#  'Space Jam': 'Fiddler on the Roof',
#  'In Love and War': 'My Favorite Brunette',
#  'The Green Mile': 'Alias: Season 2',
#  'Spanglish': 'So I Married an Axe Murderer',
#  'The Parent Trap': 'American Chopper: Season 1',
#  'The Day After Tomorrow': 'Something the Lord Made',
#  'Paint Your Wagon': 'Return of the Dragon',
#  'Universal Soldier: The Return': "She's Having A Baby",
#  'Forever Young': 'The Outlaw Josey Wales',
#  'The Nutty Professor': 'Ed Wood',
#  'Conquest of the Planet of the Apes': 'Spun',
#  'The Long Riders': 'NYPD Blue: Season 2',
#  'Turner and Hooch': 'Titanic',
#  'Legally Blonde': 'Matilda: Special Edition',
#  'Hellraiser VI: Hellseeker': 'Groundhog Day',
#  'Stepmom': 'Radio Flyer',
#  'Undisputed': 'Madison',
#  'Tortilla Soup': 'Get Shorty',
#  'Annie Hall': 'Rain Man',
#  'Stargate': 'Shrek 2',
#  'Snow Falling on Cedars': 'The End of the Affair',
#  'Osama': 'The Weather Underground',
#  'Do the Right Thing': 'High Fidelity',
#  'Less Than Zero': 'Husbands and Wives',
#  'Jeremiah Johnson': 'MASH: Season 4',
#  'Mr. Magoo': 'Star Trek: The Motion Picture',
#  'Down to Earth': 'The Trouble with Angels',
#  'The Cooler': 'The Matrix: Revolutions',
#  'Lethal Weapon 3': 'The Caine Mutiny',
#  'Jersey Girl': 'National Treasure',
#  'Ghost in the Shell 2: Innocence': 'The Matrix: Reloaded',
#  'Like Mike': 'Harry Potter and the Prisoner of Azkaban',
#  "National Lampoon's Animal House": "Footloose: Special Collector's Edition",
#  'House Party 2': 'Dangerous Minds',
#  'Cecil B. Demented': 'Heathers',
#  "But I'm a Cheerleader": 'Jimmy Neutron: Boy Genius',
#  'The Treasure of the Sierra Madre': 'The English Patient',
#  'Son in Law': 'The Avengers',
#  'Dark Blue World': 'Blade: Trinity',
#  'Quills': 'Breaking the Waves',
#  'Die Another Day': 'The Chorus',
#  'Nosferatu the Vampyre': 'Caddyshack',
#  'Paris, Texas': 'Twin Peaks: Season 1',
#  'Rocky III': 'Mad Max Beyond Thunderdome',
#  'Scooby-Doo Meets the Harlem Globetrotters': 'CSI: Season 1',
#  "Versus: Director's Cut": 'Taking Lives',
#  "What's Love Got to Do with It": 'Happy Gilmore',
#  'The Eagle Has Landed': "Michael Moore's The Awful Truth: Season 2",
#  'Poltergeist II / Poltergeist III: Double Feature': 'Hostage',
#  'Office Space': 'Muppets From Space',
#  'The Craft': 'Braveheart',
#  'The Piano': "The Wizard of Oz: Collector's Edition",
#  'Eye of the Beholder': 'Tommy Boy',
#  'Shark Tale': 'Along Came a Spider',
#  'Enough': 'Double, Double, Toil and Trouble',
#  'Paparazzi': 'Oldboy',
#  "Sharpe 1: Sharpe's Rifles": 'Mr. Bean: The Whole Bean',
#  'Remember the Titans': 'Mostly Martha',
#  'The Way We Were': 'The Simpsons: Season 1',
#  'Ghostbusters': 'Impostor',
#  'The Tigger Movie': 'VeggieTales: Esther, the Girl Who Became Queen',
#  'The Best Years of Our Lives': 'Kill Bill: Vol. 2',
#  'Jakob the Liar': 'Spartan',
#  'State and Main': 'George Carlin: Personal Favorites',
#  'Diary of a Mad Black Woman': 'A Beautiful Mind',
#  'Hitch': 'Titanic',
#  'The Adventures of Ichabod and Mr. Toad': 'Before Sunrise',
#  'Coyote Ugly': 'Tito and Me',
#  'Species': 'The West Wing: Season 3',
#  'Seven Brides for Seven Brothers: 50th Anniversary Edition': 'Braveheart',
#  'The Princess Diaries 2: Royal Engagement': 'Ransom',
#  'The Basketball Diaries': 'Kill Bill: Vol. 2',
#  'Monk: Season 1': 'Futurama: Monster Robot Maniac Fun Collection',
#  'Divine Secrets of the Ya-Ya Sisterhood': 'Spy Kids',
#  'City of Angels': 'The Powerpuff Girls Movie',
#  'Scarface: 20th Anniversary Edition': 'The Dead Zone',
#  "The Man Who Wasn't There": 'The Color of Money',
#  'Serendipity': 'Life Is Beautiful',
#  'Catch Me If You Can': 'Sid & Nancy',
#  'Kill Bill: Vol. 1': 'The Cookout',
#  'Fast Times at Ridgemont High': 'Farewell My Concubine',
#  'Selena': 'Dodgeball: A True Underdog Story',
#  'Indiana Jones and the Last Crusade': 'Tipping the Velvet',
#  'The Shining': 'First Knight',
#  'Blood: The Last Vampire': 'Highlander: Season 5',
#  'Close Encounters of the Third Kind': 'Lord of the Rings: The Return of the King: Extended Edition',
#  'Saint Jack': 'Seance on a Wet Afternoon',
#  'The Best of Friends: Season 4': 'Men in Black II',
#  'Resident Evil': 'Forever Young',
#  'The Passion of the Christ': 'Rising Sun',
#  'The Messenger: The Story of Joan of Arc': 'Hackers',
#  'Death on the Nile': 'Stargate',
#  'Gilmore Girls: Season 4': "National Lampoon's Van Wilder",
#  'Real Genius': 'Indochine',
#  'The Wings of the Dove': 'Sweet November',
#  'Message in a Bottle': 'The Recruit',
#  'Les Miserables': 'Understanding the Universe',
#  'Catch 22': 'Like Water for Chocolate',
#  'Married to the Mob': 'Screamers',
#  'Smokey and the Bandit / Smokey and the Bandit II: Double Feature': 'Reservoir Dogs',
#  'Dr. Strangelove': 'Spun',
#  'The River': 'Dogma',
#  'Britannic': 'Finding Forrester',
#  'The Aviator': 'The Breakfast Club',
#  'Blow Up': 'Futurama: Vol. 1',
#  'Wild Things': 'From Dusk Till Dawn',
#  'Rebecca': "That '70s Show: Season 1",
#  'Five Easy Pieces': 'Gandhi',
#  'Where the Money Is': 'Mr. Sardonicus',
#  'Sweet November': 'Star Wars: Episode I: The Phantom Menace',
#  'Menace II Society': 'I, Robot',
#  'Shrek (Full-screen)': 'Sneakers',
#  'Reality Bites': 'Sex and the City: Season 1',
#  'Flying Leathernecks': 'Lonesome Dove',
#  'Three Amigos': 'Saving Grace',
#  'Mr. Mom': 'Still, We Believe: The Boston Red Sox Movie',
#  'Love & Basketball': 'Antwone Fisher',
#  'The Life of David Gale': 'Sex and the City: Season 6: Part 2',
#  'The Natural': 'In the Bedroom',
#  'Heat: Special Edition': 'Welcome to Mooseport',
#  'Big Trouble in Little China': 'Children of Paradise',
#  'Mighty Aphrodite': 'Ray',
#  'Ronin': 'Garden State',
#  'Never Been Kissed': 'Armageddon',
#  'Original Sin': 'Batteries Not Included',
#  'Being John Malkovich': 'Dances With Wolves: Special Edition',
#  'Northern Exposure: Season 2': 'Jaws',
#  'White Squall': 'A Home of Our Own',
#  'Swingers': 'Freaks & Geeks: The Complete Series',
#  'Telling Lies in America': "Breakfast at Tiffany's",
#  "Look Who's Talking": 'Turner and Hooch',
#  'Road Trip': 'American Pie 2',
#  'Henry: Portrait of a Serial Killer': 'Marathon Man',
#  'Blow': 'Oz: Season 3'}

# %%
actions
# Out:
# {'4352': '6872',
#  '6872': '636',
#  '636': '173',
#  '173': '2162',
#  '2162': '253',
#  '253': '788',
#  '1547': '311',
#  '311': '13847',
#  '13847': '4479',
#  '4479': '2161',
#  '2161': '253',
#  '788': '1167',
#  '1167': '5738',
#  '15769': '334',
#  '16843': '267',
#  '11340': '11153',
#  '2612': '1176',
#  '2782': '14382',
#  '14644': '734',
#  '9756': '1267',
#  '10554': '58',
#  '13795': '17059',
#  '12293': '338',
#  '10231': '963',
#  '14467': '2456',
#  '9188': '12605',
#  '9584': '287',
#  '17023': '8197',
#  '17066': '3478',
#  '16707': '1073',
#  '11182': '2664',
#  '3624': '1144',
#  '14149': '17079',
#  '9458': '677',
#  '9800': '2913',
#  '16605': '4847',
#  '10421': '6974',
#  '16384': '3091',
#  '14618': '6099',
#  '11026': '4798',
#  '2372': '5162',
#  '17149': '1890',
#  '11754': '2158',
#  '13462': '4686',
#  '12828': '5917',
#  '14313': '78',
#  '295': '2809',
#  '7336': '11701',
#  '8872': '1719',
#  '4996': '6138',
#  '12317': '14999',
#  '11165': '1353',
#  '6180': '4306',
#  '5653': '381',
#  '4670': '341',
#  '14016': '1145',
#  '15578': '16',
#  '15582': '2585',
#  '4392': '57',
#  '3256': '1370',
#  '11283': '6959',
#  '3046': '454',
#  '15818': '1709',
#  '14194': '473',
#  '2938': '138',
#  '2743': '2057',
#  '9757': '571',
#  '10461': '5601',
#  '14763': '313',
#  '4432': '6231',
#  '8832': '2139',
#  '8627': '132',
#  '4227': '7230',
#  '3161': '11152',
#  '13651': '3841',
#  '5582': '11522',
#  '17057': '15671',
#  '3151': '7745',
#  '16522': '2112',
#  '1905': '269',
#  '2532': '2173',
#  '7331': '252',
#  '12582': '1103',
#  '10042': '152',
#  '7193': '16879',
#  '607': '4727',
#  '2200': '8116',
#  '14215': '9340',
#  '16721': '2778',
#  '15058': '9132',
#  '4123': '4977',
#  '13392': '563',
#  '3320': '313',
#  '17169': '3078',
#  '14660': '32',
#  '8050': '1408',
#  '2252': '9685',
#  '1975': '10123',
#  '5035': '12690',
#  '17053': '692',
#  '1682': '14691',
#  '15388': '3035',
#  '1428': '1703',
#  '8086': '17157',
#  '14712': '1372',
#  '11152': '345',
#  '7330': '1700',
#  '6070': '2803',
#  '7234': '6408',
#  '11490': '563',
#  '12299': '896',
#  '10446': '10152',
#  '3814': '10225',
#  '7963': '1256',
#  '8782': '681',
#  '16181': '11882',
#  '12243': '6989',
#  '7696': '5401',
#  '5112': '16703',
#  '17295': '108',
#  '3282': '17387',
#  '8327': '13488',
#  '10123': '4214',
#  '1987': '2599',
#  '12155': '2192',
#  '12690': '3160',
#  '8406': '7735',
#  '8803': '6833',
#  '6445': '1435',
#  '14646': '12140',
#  '1700': '2782',
#  '14039': '463',
#  '17562': '2813',
#  '1466': '3180',
#  '15730': '125',
#  '16668': '7391',
#  '8744': '5571',
#  '7624': '45',
#  '670': '1295',
#  '3972': '636',
#  '3223': '14031',
#  '12092': '12003',
#  '7057': '3893',
#  '13388': '30',
#  '2443': '2178',
#  '14591': '13728',
#  '8517': '7221',
#  '6735': '1202',
#  '5614': '14856',
#  '1110': '12293',
#  '4394': '77',
#  '12896': '378',
#  '14670': '843',
#  '8467': '16',
#  '11886': '548',
#  '16147': '3078',
#  '9598': '9160',
#  '5054': '1843',
#  '6994': '1759',
#  '11648': '5496',
#  '10451': '1902',
#  '16552': '14312',
#  '4508': '3021',
#  '9882': '438',
#  '5695': '4271',
#  '9625': '7767',
#  '4951': '673',
#  '2675': '1590',
#  '13865': '32',
#  '13441': '2342',
#  '4581': '8524',
#  '16459': '14187',
#  '3017': '14198',
#  '11859': '15296',
#  '2953': '759',
#  '11042': '4345',
#  '14382': '3267',
#  '14667': '454',
#  '15052': '2310',
#  '11337': '359',
#  '8773': '8107',
#  '16587': '8163',
#  '8116': '7755',
#  '4656': '3903',
#  '7814': '798',
#  '7169': '104',
#  '14590': '5515',
#  '10337': '550',
#  '15063': '2470',
#  '10170': '4256',
#  '15043': '2874',
#  '6274': '348',
#  '2112': '2178',
#  '7589': '4366',
#  '6720': '1020',
#  '17004': '1208',
#  '3413': '732',
#  '12493': '257',
#  '6240': '76',
#  '4914': '2016',
#  '6922': '1412',
#  '12003': '4847',
#  '17031': '9728',
#  '5787': '889',
#  '10378': '5293',
#  '12311': '11544',
#  '11168': '57',
#  '3427': '1530',
#  '14367': '13784',
#  '11479': '1687',
#  '9733': '12239',
#  '11279': '334',
#  '3315': '4633',
#  '6911': '454',
#  '3925': '8848',
#  '6632': '3128',
#  '14047': '6012',
#  '9111': '325',
#  '15394': '10379',
#  '1145': '6235',
#  '5317': '17308',
#  '8717': '191',
#  '2890': '3624',
#  '953': '12355',
#  '5223': '994',
#  '11265': '1435',
#  '17479': '992',
#  '6692': '2371',
#  '7704': '1590',
#  '12570': '7767',
#  '16948': '1743',
#  '9840': '1856',
#  '14393': '2342',
#  '6021': '563',
#  '2152': '14487',
#  '4216': '662',
#  '7890': '267',
#  '10162': '752',
#  '6437': '6974',
#  '12918': '285',
#  '5926': '543',
#  '16452': '108',
#  '15137': '2809',
#  '10951': '7984',
#  '16797': '4798',
#  '6223': '9051',
#  '14978': '15769',
#  '8295': '11400',
#  '16265': '2942',
#  '1539': '83',
#  '16082': '9728',
#  '7650': '2395',
#  '11677': '2162',
#  '14527': '6274',
#  '16698': '5318',
#  '15182': '1983',
#  '819': '3997',
#  '11277': '4996',
#  '10545': '30',
#  '7895': '2955',
#  '3225': '658',
#  '758': '6',
#  '9818': '1861',
#  '361': '14240',
#  '15901': '629',
#  '17113': '152',
#  '12186': '9051',
#  '15509': '1476',
#  '14158': '175',
#  '6972': '14134',
#  '7695': '8327',
#  '10607': '1295',
#  '16242': '2549',
#  '11064': '14254',
#  '5360': '8405',
#  '3122': '215',
#  '4995': '48',
#  '5793': '5778',
#  '10230': '143',
#  '6797': '9144',
#  '10827': '2122',
#  '676': '1664',
#  '5727': '3427',
#  '14240': '498',
#  '13629': '2101',
#  '14538': '7600',
#  '3368': '4972',
#  '8666': '571',
#  '14725': '471',
#  '7710': '6428',
#  '17622': '3864',
#  '5342': '312',
#  '9623': '2376',
#  '6266': '2290',
#  '4306': '13073',
#  '12232': '12918',
#  '2395': '2803',
#  '12221': '1432',
#  '14477': '12870',
#  '11047': '378',
#  '17015': '11427',
#  '1650': '378',
#  '7511': '6475',
#  '3860': '83',
#  '15472': '11283',
#  '16118': '13673',
#  '5496': '316',
#  '11904': '175',
#  '9120': '3309',
#  '14358': '11029',
#  '9433': '5762',
#  '13451': '6807',
#  '5997': '3224',
#  '8387': '2533',
#  '2057': '290',
#  '1709': '443',
#  '1843': '2916',
#  '11521': '3079',
#  '15843': '4005',
#  '3333': '3541',
#  '3371': '6029',
#  '4577': '3418',
#  '9426': '8904',
#  '7416': '378',
#  '17014': '674',
#  '13015': '2558',
#  '7470': '2809',
#  '16912': '843',
#  '12365': '1066',
#  '357': '3128',
#  '16882': '5137',
#  '8764': '3684',
#  '2740': '282',
#  '15107': '4389',
#  '329': '2953',
#  '16512': '15786',
#  '5181': '2578',
#  '5991': '10254',
#  '16793': '457',
#  '9481': '10713',
#  '1744': '8107',
#  '7364': '341',
#  '17215': '5924',
#  '7155': '442',
#  '14584': '8',
#  '17621': '14584',
#  '15124': '115',
#  '16740': '2532',
#  '7632': '2300',
#  '15246': '4824',
#  '1027': '311',
#  '14890': '5515',
#  '3835': '1642',
#  '10774': '16954',
#  '4753': '3385',
#  '8232': '1357',
#  '12891': '1466',
#  '6134': '3756',
#  '2643': '2803',
#  '3290': '2379',
#  '14579': '313',
#  '9257': '8596',
#  '6237': '8372',
#  '9524': '457',
#  '9170': '7070',
#  '5243': '16969',
#  '15436': '14780',
#  '7219': '8832',
#  '12785': '723',
#  '3872': '11040',
#  '15156': '7917',
#  '6631': '2443',
#  '10778': '199',
#  '313': '516',
#  '6971': '2430',
#  '289': '2103',
#  '11544': '3648',
#  '11812': '6807',
#  '14265': '9498',
#  '9635': '10830',
#  '7828': '2803',
#  '5333': '809',
#  '11638': '13580',
#  '12205': '55',
#  '4977': '2809',
#  '11573': '311',
#  '3816': '462',
#  '16412': '313',
#  '8677': '1142',
#  '13317': '886',
#  '1394': '3282',
#  '4640': '12161',
#  '14103': '1032',
#  '17328': '7416',
#  '11062': '9279',
#  '11480': '1495',
#  '2389': '2430',
#  '5802': '12293',
#  '191': '413',
#  '2660': '10550',
#  '11882': '896',
#  '16339': '843',
#  '16858': '4045',
#  '10894': '11022',
#  '16272': '3121',
#  '12476': '13748',
#  '985': '12974',
#  '1798': '44',
#  '5607': '16707',
#  '5732': '10042',
#  '17385': '1861',
#  '2617': '16',
#  '12172': '829',
#  '11005': '2001',
#  '13519': '270',
#  '6339': '674',
#  '6119': '3590',
#  '16733': '256',
#  '4877': '240',
#  '16565': '752',
#  '12015': '2000',
#  '2539': '2795',
#  '798': '1682',
#  '3684': '4690',
#  '3106': '4919',
#  '3331': '674',
#  '9132': '9959',
#  '13081': '7586',
#  '1792': '1902',
#  '7779': '872',
#  '10080': '2601',
#  '11090': '1138',
#  '15715': '692',
#  '8881': '13090',
#  '13534': '305',
#  '9471': '33',
#  '4734': '31',
#  '15788': '16377',
#  '17088': '682',
#  '11651': '44',
#  '16840': '15327',
#  '16302': '1487',
#  '6350': '14296',
#  '16825': '13614',
#  '16389': '8806',
#  '12084': '2800',
#  '9731': '4633',
#  '3851': '8',
#  '11356': '348',
#  '17361': '6972',
#  '14134': '2782',
#  '3267': '311',
#  '629': '28',
#  '28': '3046',
#  '454': '334',
#  '334': '937',
#  '937': '3917',
#  '3917': '14109',
#  '14109': '12582',
#  '1103': '4847',
#  '4847': '1129',
#  '1129': '985',
#  '12974': '4739',
#  '4739': '6235',
#  '6235': '1017',
#  '1017': '161',
#  '161': '16969',
#  '16969': '4123',
#  '2809': '262',
#  '262': '270',
#  '270': '1216',
#  '1216': '886',
#  '886': '15296',
#  '15296': '8379',
#  '8379': '5762',
#  '5762': '1552',
#  '1552': '175',
#  '175': '2015',
#  '2015': '5862',
#  '5862': '5665',
#  '5665': '1470',
#  '1470': '1798',
#  '44': '83',
#  '83': '483',
#  '483': '5732',
#  '152': '241',
#  '241': '313',
#  '516': '199',
#  '199': '3309',
#  '3309': '191',
#  '13342': '468',
#  '6030': '7293',
#  '1833': '10147',
#  '15477': '1180',
#  '16532': '290',
#  '13501': '5539',
#  '12188': '215',
#  '13298': '2153',
#  '15646': '12672',
#  '8376': '2457',
#  '13216': '1428',
#  '4356': '2734',
#  '10820': '2743',
#  '4345': '8045',
#  '11153': '6003',
#  '11303': '468',
#  '17395': '1877',
#  '5401': '15545',
#  '4599': '143',
#  '1482': '14482',
#  '15540': '424',
#  '16158': '2009',
#  '10730': '5515',
#  '13622': '18',
#  '1202': '16063',
#  '8687': '2775',
#  '10226': '3917',
#  '10359': '5519',
#  '10583': '6702',
#  '8743': '629',
#  '16879': '2783',
#  '16772': '1208',
#  '12834': '10607',
#  '8226': '330',
#  '11663': '2153',
#  '14856': '1123',
#  '6497': '10774',
#  '10734': '2172',
#  '4472': '6037',
#  '15887': '3777',
#  '9689': '5854',
#  '3713': '4043',
#  '16208': '837',
#  '8357': '6797',
#  '8301': '1882',
#  '9681': '173',
#  '6931': '6927',
#  '17355': '11152',
#  '3553': '6912',
#  '2192': '1932',
#  '6591': '595',
#  '8585': '12034',
#  '2371': '3390',
#  '8904': '17709',
#  '13728': '229',
#  '818': '1245',
#  '4315': '8038',
#  '15496': '5926',
#  '14691': '5468',
#  '14312': '6042',
#  '6206': '8339',
#  '9051': '724',
#  '9728': '2782',
#  '3239': '1843',
#  '12195': '1795',
#  '3490': '17724',
#  '16201': '17154',
#  '13359': '227',
#  '3920': '199',
#  '15316': '11369',
#  '5561': '14777',
#  '11209': '14869',
#  '7019': '175',
#  '14968': '1035',
#  '13923': '5704',
#  '12672': '5522',
#  '5069': '168',
#  '6386': '5775',
#  '6408': '8687',
#  '13302': '8851',
#  '7928': '6454',
#  '2499': '248',
#  '3418': '267',
#  '6826': '2638',
#  '4056': '14507',
#  '7833': '175',
#  '1160': '255',
#  '8840': '431',
#  '4545': '1616',
#  '4515': '357',
#  '9741': '1357',
#  '12931': '2862',
#  '14657': '10036',
#  '6166': '822',
#  '5571': '14240',
#  '10125': '329',
#  '16676': '199',
#  '38': '11040',
#  '14999': '15818',
#  '10872': '6739',
#  '3962': '6833',
#  '15345': '10277',
#  '16415': '2992',
#  '17644': '2862',
#  '2379': '1435',
#  '5085': '7234',
#  '13384': '1384',
#  '14296': '133',
#  '12914': '7735',
#  '5667': '17324',
#  '9235': '7057',
#  '6908': '4820',
#  '17672': '629',
#  '12732': '746',
#  '17627': '10429',
#  '12470': '5087',
#  '1180': '3605',
#  '11740': '3290',
#  '16390': '5614',
#  '6050': '1799',
#  '2102': '4697',
#  '10375': '3446',
#  '3649': '569',
#  '11781': '1432',
#  '3801': '1191',
#  '13129': '20',
#  '8571': '1216',
#  '15995': '9340',
#  '4488': '831',
#  '7064': '919',
#  '2779': '6029',
#  '4256': '47',
#  '12586': '5738',
#  '12497': '2319',
#  '15597': '2660',
#  '464': '6445',
#  '14869': '7779',
#  '12911': '2342',
#  '257': '11198',
#  '5601': '215',
#  '16992': '2095',
#  '88': '434',
#  '1890': '171',
#  '5877': '2913',
#  '5765': '12249',
#  '14550': '3423',
#  '12870': '12305',
#  '1865': '4640',
#  '6196': '15922',
#  '8384': '851',
#  '15764': '516',
#  '14961': '6205',
#  '5708': '209',
#  '16499': '3962',
#  '14219': '253',
#  '10682': '359',
#  '4067': '453',
#  '13195': '362',
#  '11952': '175',
#  '7773': '57',
#  '9144': '13614',
#  '11775': '2212',
#  '2342': '7617',
#  '16016': '5223',
#  '1476': '3226',
#  '10835': '668',
#  '16872': '457',
#  '16755': '17328',
#  '8981': '4520',
#  '11092': '13688',
#  '5924': '3668',
#  '12161': '6336',
#  '15445': '10225',
#  '4912': '175',
#  '15209': '1615',
#  '3638': '14454',
#  '238': '5693',
#  '5809': '32',
#  '10139': '2290',
#  '12435': '16930',
#  '16438': '5614',
#  '11929': '662',
#  '7922': '494',
#  '15975': '2578',
#  '15997': '15296',
#  '3047': '1590',
#  '7032': '1495',
#  '3875': '329',
#  '6013': '4109',
#  '14928': '13052',
#  '2920': '2823',
#  '4805': '359',
#  '15943': '199',
#  '15945': '9433',
#  '10073': '12',
#  '16377': '5292',
#  '6475': '3728',
#  '16596': '7124',
#  '15205': '16278',
#  '11435': '1300',
#  '8987': '4147',
#  '3433': '17424',
#  '5628': '311',
#  '16259': '367',
#  '7606': '3888',
#  '9205': '16879',
#  '17308': '2523',
#  '10566': '10225',
#  '9617': '1528',
#  '4429': '8194',
#  '4790': '7055',
#  '8159': '4640',
#  '3817': '3938',
#  '6637': '12322',
#  '11891': '52',
#  '7173': '312',
#  '7435': '156',
#  '8586': '15183',
#  '731': '1902',
#  '11110': '371',
#  '6874': '468',
#  '3610': '1969',
#  '13471': '17169',
#  '17112': '3925',
#  '17491': '12338',
#  '12605': '4256',
#  '9903': '896',
#  '3758': '2922',
#  '4586': '563',
#  '17412': '3148',
#  '5033': '289',
#  '16890': '3138',
#  '16538': '14259',
#  '7509': '167',
#  '11840': '9051',
#  '14327': '10982',
#  '9565': '10236',
#  '11884': '2162',
#  '6808': '197',
#  '14457': '8764',
#  '8621': '248',
#  '9027': '406',
#  '13614': '2804',
#  '6708': '2782',
#  '1367': '3605',
#  '6345': '5318',
#  '5345': '12299',
#  '13524': '4268',
#  '13675': '10582',
#  '15282': '5513',
#  '15844': '97',
#  '3071': '1020',
#  '17560': '216',
#  '16931': '2176',
#  '14155': '457',
#  '6630': '108',
#  '12096': '477',
#  '11134': '1180',
#  '17324': '3124',
#  '13691': '7517',
#  '13102': '1777',
#  '14889': '4427',
#  '2735': '2782',
#  '13887': '15472',
#  '6219': '457',
#  '16524': '316',
#  '6760': '3466',
#  '14909': '84',
#  '6205': '1646',
#  '15450': '2139',
#  '2800': '13593',
#  '8644': '5591',
#  '14454': '225',
#  '13636': '4496',
#  '15545': '5401',
#  '16954': '8801',
#  '12034': '550',
#  '2812': '657',
#  '15702': '14961',
#  '508': '12868',
#  '7158': '3427',
#  '15853': '3433',
#  '4266': '1027',
#  '5462': '3680',
#  '11912': '3817',
#  '7815': '1509',
#  '7483': '734',
#  '17638': '148',
#  '2866': '1428',
#  '9395': '17291',
#  '14147': '2443',
#  '12275': '16',
#  '6804': '175',
#  '5515': '367',
#  '17357': '329',
#  '2860': '7937',
#  '12966': '6797',
#  '11980': '2532',
#  '330': '9298',
#  '7642': '215',
#  '7127': '4633',
#  '7383': '12433',
#  '148': '9886',
#  '8046': '5496',
#  '14621': '4862',
#  '4778': '13129',
#  '11075': '1692',
#  '14960': '660',
#  '13217': '366',
#  '9438': '7928',
#  '7513': '12530',
#  '9378': '7971',
#  '4697': '9508',
#  '12843': '5605',
#  '6988': '886',
#  '15816': '3917',
#  '13582': '6972',
#  '3312': '9509',
#  '2122': '4545',
#  '17536': '798',
#  '833': '3812',
#  '13439': '4978',
#  '15799': '4506',
#  '2594': '9205',
#  '10436': '10170',
#  '5642': '1370',
#  '16792': '17687'}

# %%
values
# Out:
# {'4352': 0.02510460251046025,
#  '6872': 0.02149758454106281,
#  '636': 0.016129032258064526,
#  '173': 0.05932432432432431,
#  '2162': 0.03578947368421053,
#  '253': 0.03257273245864232,
#  '1547': 0.015679190751445082,
#  '311': 0.05261363636363639,
#  '13847': 0.03305626598465474,
#  '4479': 0.019387755102040827,
#  '2161': 0.037981781376518226,
#  '788': -0.011764705882352944,
#  '1167': -1.0,
#  '15769': -0.9974762611275966,
#  '16843': -1.0,
#  '11340': -1.0,
#  '2612': -1.0,
#  '2782': -0.05008536199810307,
#  '14644': -1.0,
#  '9756': -1.0,
#  '10554': -1.0,
#  '13795': -1.0,
#  '12293': -1.0,
#  '10231': -1.0,
#  '14467': -1.0,
#  '9188': -1.0,
#  '9584': -1.0,
#  '17023': -1.0,
#  '17066': -1.0,
#  '16707': -1.0,
#  '11182': -1.0,
#  '3624': -1.0,
#  '14149': -1.0,
#  '9458': -1.0,
#  '9800': -1.0,
#  '16605': -1.0,
#  '10421': -1.0,
#  '16384': -1.0,
#  '14618': -1.0,
#  '11026': -1.0,
#  '2372': -1.0,
#  '17149': -1.0,
#  '11754': -1.0,
#  '13462': -1.0,
#  '12828': -1.0,
#  '14313': -1.0,
#  '295': -1.0,
#  '7336': -1.0,
#  '8872': -1.0,
#  '4996': -1.0,
#  '12317': -1.0,
#  '11165': -1.0,
#  '6180': -1.0,
#  '5653': -1.0,
#  '4670': -1.0,
#  '14016': -1.0,
#  '15578': -1.0,
#  '15582': -1.0,
#  '4392': -1.0,
#  '3256': -1.0,
#  '11283': -1.0,
#  '3046': 0.03214285714285714,
#  '15818': -1.0,
#  '14194': -1.0,
#  '2938': -1.0,
#  '2743': -1.0,
#  '9757': -1.0,
#  '10461': -1.0,
#  '14763': -1.0,
#  '4432': -1.0,
#  '8832': -1.0,
#  '8627': -1.0,
#  '4227': -1.0,
#  '3161': -1.0,
#  '13651': -1.0,
#  '5582': -1.0,
#  '17057': -1.0,
#  '3151': -1.0,
#  '16522': -1.0,
#  '1905': -1.0,
#  '2532': -1.0,
#  '7331': -1.0,
#  '12582': 0.025568181818181813,
#  '10042': 0.02548076923076923,
#  '7193': -1.0,
#  '607': -1.0,
#  '2200': -1.0,
#  '14215': -1.0,
#  '16721': -1.0,
#  '15058': -1.0,
#  '4123': -0.06337662337662339,
#  '13392': -1.0,
#  '3320': -1.0,
#  '17169': -1.0,
#  '14660': -1.0,
#  '8050': -1.0,
#  '2252': -1.0,
#  '1975': -1.0,
#  '5035': -1.0,
#  '17053': -1.0,
#  '1682': -1.0,
#  '15388': -1.0,
#  '1428': -1.0,
#  '8086': -1.0,
#  '14712': -1.0,
#  '11152': -1.0,
#  '7330': -1.0,
#  '6070': -1.0,
#  '7234': -1.0,
#  '11490': -1.0,
#  '12299': -1.0,
#  '10446': -1.0,
#  '3814': -1.0,
#  '7963': -1.0,
#  '8782': -1.0,
#  '16181': -1.0,
#  '12243': -1.0,
#  '7696': -1.0,
#  '5112': -1.0,
#  '17295': -1.0,
#  '3282': -1.0,
#  '8327': -1.0,
#  '10123': -1.0,
#  '1987': -1.0,
#  '12155': -1.0,
#  '12690': -1.0,
#  '8406': -1.0,
#  '8803': -1.0,
#  '6445': -1.0,
#  '14646': -1.0,
#  '1700': -1.09,
#  '14039': -1.0,
#  '17562': -1.0,
#  '1466': -1.0,
#  '15730': -1.0,
#  '16668': -1.0,
#  '8744': -1.0,
#  '7624': -1.0,
#  '670': -1.0,
#  '3972': -0.9985483870967743,
#  '3223': -1.0,
#  '12092': -1.0,
#  '7057': -1.0,
#  '13388': -1.0,
#  '2443': -1.0,
#  '14591': -1.0,
#  '8517': -1.0,
#  '6735': -1.0,
#  '5614': -1.0,
#  '1110': -1.09,
#  '4394': -1.0,
#  '12896': -1.0,
#  '14670': -1.0,
#  '8467': -1.0,
#  '11886': -1.0,
#  '16147': -1.0,
#  '9598': -1.0,
#  '5054': -1.0,
#  '6994': -1.0,
#  '11648': -1.0,
#  '10451': -1.0,
#  '16552': -1.0,
#  '4508': -1.0,
#  '9882': -1.0,
#  '5695': -1.0,
#  '9625': -1.0,
#  '4951': -1.0,
#  '2675': -1.0,
#  '13865': -1.0,
#  '13441': -1.0,
#  '4581': -1.0,
#  '16459': -1.0,
#  '3017': -1.0,
#  '11859': -1.0,
#  '2953': -1.0,
#  '11042': -1.0,
#  '14382': 0.02266553480475382,
#  '14667': -0.9995427098674523,
#  '15052': -1.0,
#  '11337': -1.0,
#  '8773': -1.0,
#  '16587': -1.0,
#  '8116': -1.0,
#  '4656': -1.0,
#  '7814': -1.0,
#  '7169': -1.0,
#  '14590': -1.0,
#  '10337': -1.0,
#  '15063': -1.0,
#  '10170': -1.0,
#  '15043': -1.0,
#  '6274': -1.0,
#  '2112': -1.0,
#  '7589': -1.0,
#  '6720': -1.0,
#  '17004': -1.0,
#  '3413': -1.0,
#  '12493': -1.0,
#  '6240': -1.0,
#  '4914': -1.0,
#  '6922': -1.0,
#  '12003': -1.0,
#  '17031': -1.0,
#  '5787': -1.0,
#  '10378': -1.0,
#  '12311': -1.0,
#  '11168': -1.0,
#  '3427': -1.0,
#  '14367': -1.0,
#  '11479': -1.0,
#  '9733': -1.0,
#  '11279': -1.0,
#  '3315': -1.0,
#  '6911': -1.0,
#  '3925': -1.0,
#  '6632': -1.0,
#  '14047': -1.0,
#  '9111': -1.0,
#  '15394': -1.0,
#  '1145': -0.997906976744186,
#  '5317': -1.0,
#  '8717': -1.0,
#  '2890': -1.09,
#  '953': -1.0,
#  '5223': -1.0,
#  '11265': -1.0,
#  '17479': -1.0,
#  '6692': -1.0,
#  '7704': -1.0,
#  '12570': -1.0,
#  '16948': -1.0,
#  '9840': -1.0,
#  '14393': -1.0,
#  '6021': -1.0,
#  '2152': -1.0,
#  '4216': -1.0,
#  '7890': -1.0,
#  '10162': -1.0,
#  '6437': -1.0,
#  '12918': -1.0,
#  '5926': -1.0,
#  '16452': -1.0,
#  '15137': -1.0,
#  '10951': -1.0,
#  '16797': -1.0,
#  '6223': -1.0,
#  '14978': -1.09,
#  '8295': -1.0,
#  '16265': -1.0,
#  '1539': -1.0,
#  '16082': -1.0,
#  '7650': -1.0,
#  '11677': -0.996778947368421,
#  '14527': -1.09,
#  '16698': -1.0,
#  '15182': -1.0,
#  '819': -1.0,
#  '11277': -1.09,
#  '10545': -1.0,
#  '7895': -1.0,
#  '3225': -1.0,
#  '758': -1.0,
#  '9818': -1.0,
#  '361': -1.0,
#  '15901': -1.0,
#  '17113': -1.0,
#  '12186': -1.0,
#  '15509': -1.0,
#  '14158': -1.0,
#  '6972': 0.03606965174129353,
#  '7695': -1.09,
#  '10607': -1.0,
#  '16242': -1.0,
#  '11064': -1.0,
#  '5360': -1.0,
#  '3122': -1.0,
#  '4995': -1.0,
#  '5793': -1.0,
#  '10230': -1.0,
#  '6797': -1.0,
#  '10827': -1.0,
#  '676': -1.0,
#  '5727': -1.09,
#  '14240': -1.0,
#  '13629': -1.0,
#  '14538': -1.0,
#  '3368': -1.0,
#  '8666': -1.0,
#  '14725': -1.0,
#  '7710': -1.0,
#  '17622': -1.0,
#  '5342': -1.0,
#  '9623': -1.0,
#  '6266': -1.0,
#  '4306': -1.0,
#  '12232': -1.09,
#  '2395': -1.0,
#  '12221': -1.0,
#  '14477': -1.0,
#  '11047': -1.0,
#  '17015': -1.0,
#  '1650': -1.0,
#  '7511': -1.0,
#  '3860': -1.0,
#  '15472': -1.09,
#  '16118': -1.0,
#  '5496': -1.0,
#  '11904': -1.0,
#  '9120': -1.0,
#  '14358': -1.0,
#  '9433': -1.0,
#  '13451': -1.0,
#  '5997': -1.0,
#  '8387': -1.0,
#  '2057': -1.0,
#  '1709': -1.0,
#  '1843': -1.0,
#  '11521': -1.0,
#  '15843': -1.0,
#  '3333': -1.0,
#  '3371': -1.0,
#  '4577': -1.0,
#  '9426': -1.0,
#  '7416': -1.0,
#  '17014': -1.0,
#  '13015': -1.0,
#  '7470': -1.0,
#  '16912': -1.0,
#  '12365': -1.0,
#  '357': -1.0,
#  '16882': -1.0,
#  '8764': -1.0,
#  '2740': -1.0,
#  '15107': -1.0,
#  '329': -1.09,
#  '16512': -1.0,
#  '5181': -1.0,
#  '5991': -1.0,
#  '16793': -1.0,
#  '9481': -1.0,
#  '1744': -1.0,
#  '7364': -1.0,
#  '17215': -1.0,
#  '7155': -1.0,
#  '14584': -1.0,
#  '17621': -1.0981,
#  '15124': -1.0,
#  '16740': -1.09,
#  '7632': -1.0,
#  '15246': -1.0,
#  '1027': -0.9952647727272729,
#  '14890': -1.0,
#  '3835': -1.0,
#  '10774': -1.0,
#  '4753': -1.0,
#  '8232': -1.0,
#  '12891': -1.09,
#  '6134': -1.0,
#  '2643': -1.0,
#  '3290': -1.0,
#  '14579': -1.0,
#  '9257': -1.0,
#  '6237': -1.0,
#  '9524': -1.0,
#  '9170': -1.0,
#  '5243': -1.0,
#  '15436': -1.0,
#  '7219': -1.09,
#  '12785': -1.0,
#  '3872': -1.0,
#  '15156': -1.0,
#  '6631': -1.09,
#  '10778': -1.0,
#  '313': 0.022879177377892024,
#  '6971': -1.0,
#  '289': -1.0,
#  '11544': -1.0,
#  '11812': -1.0,
#  '14265': -1.0,
#  '9635': -1.0,
#  '7828': -1.0,
#  '5333': -1.0,
#  '11638': -1.0,
#  '12205': -1.0,
#  '4977': 0.012039660056657221,
#  '11573': -0.9952647727272729,
#  '3816': -1.0,
#  '16412': -1.09,
#  '8677': -1.0,
#  '13317': -1.0,
#  '1394': -1.09,
#  '4640': -1.0,
#  '14103': -1.0,
#  '17328': -1.09,
#  '11062': -1.0,
#  '11480': -1.0,
#  '2389': -1.0,
#  '5802': -1.09,
#  '191': -1.0,
#  '2660': -1.0,
#  '11882': -1.0,
#  '16339': -1.0,
#  '16858': -1.0,
#  '10894': -1.0,
#  '16272': -1.0,
#  '12476': -1.0,
#  '985': 0.035896180215475026,
#  '1798': 0.011085972850678739,
#  '5607': -1.09,
#  '5732': -0.015674633770239022,
#  '17385': -1.0,
#  '2617': -1.0,
#  '12172': -1.0,
#  '11005': -1.0,
#  '13519': -1.0,
#  '6339': -1.0,
#  '6119': -1.0,
#  '16733': -1.0,
#  '4877': -1.0,
#  '16565': -1.0,
#  '12015': -1.0,
#  '2539': -1.0,
#  '798': -1.09,
#  '3684': -1.0,
#  '3106': -1.0,
#  '3331': -1.0,
#  '9132': -1.0,
#  '13081': -1.0,
#  '1792': -1.0,
#  '7779': -1.0,
#  '10080': -1.0,
#  '11090': -1.0,
#  '15715': -1.0,
#  '8881': -1.0,
#  '13534': -1.0,
#  '9471': -1.0,
#  '4734': -1.0,
#  '15788': -1.0,
#  '17088': -1.0,
#  '11651': -1.0,
#  '16840': -1.0,
#  '16302': -1.0,
#  '6350': -1.0,
#  '16825': -1.0,
#  '16389': -1.0,
#  '12084': -1.0,
#  '9731': -1.0,
#  '3851': -1.0,
#  '11356': -1.0,
#  '17361': -0.06431658209199541,
#  '14134': -0.03212182230052859,
#  '3267': 0.02041441802417236,
#  '629': 0.015304878048780491,
#  '28': -0.023510638297872356,
#  '454': 0.005081001472754055,
#  '334': 0.02804154302670623,
#  '937': 0.027028238458090548,
#  '3917': 0.029833074534161487,
#  '14109': -0.05095463609172483,
#  '1103': 0.048979591836734705,
#  '4847': 0.026642335766423365,
#  '1129': -0.06860432164364151,
#  '12974': 0.0270193401592719,
#  '4739': 0.03456501403180543,
#  '6235': 0.023255813953488372,
#  '1017': 0.015384615384615375,
#  '161': 0.046477611940298515,
#  '16969': -0.07003464203233258,
#  '2809': 0.02959183673469388,
#  '262': 0.025115207373271886,
#  '270': 0.017999999999999995,
#  '1216': 0.03573956121726823,
#  '886': 0.07290697674418603,
#  '15296': 0.03510638297872339,
#  '8379': 0.037370867768595044,
#  '5762': 0.017553191489361696,
#  '1552': 0.024439584472389277,
#  '175': 0.028546712802768173,
#  '2015': 0.041622441243366184,
#  '5862': 0.020627376425855506,
#  '5665': 0.026101010101010094,
#  '1470': -0.04676640131759539,
#  '44': 0.022673267326732673,
#  '83': 0.013606726149622507,
#  '483': -0.02876651982378854,
#  '152': 0.037851518560179986,
#  '241': -0.07744721689059501,
#  '516': 0.024250325945241194,
#  '199': -0.0010033444816053506,
#  '3309': -1.09,
#  '13342': -1.0,
#  '6030': -1.0,
#  '1833': -1.0,
#  '15477': -1.0,
#  '16532': -1.0,
#  '13501': -1.0,
#  '12188': -1.0,
#  '13298': -1.0,
#  '15646': -1.0,
#  '8376': -1.0,
#  '13216': -1.09,
#  '4356': -1.0,
#  '10820': -1.09,
#  '4345': -1.0,
#  '11153': -1.0,
#  '11303': -1.0,
#  '17395': -1.0,
#  '5401': -1.0,
#  '4599': -1.0,
#  '1482': -1.0,
#  '15540': -1.0,
#  '16158': -1.0,
#  '10730': -1.0,
#  '13622': -1.0,
#  '1202': -1.0,
#  '8687': -1.0,
#  '10226': -0.9973150232919255,
#  '10359': -1.0,
#  '10583': -1.0,
#  '8743': -0.9986225609756098,
#  '16879': -1.0,
#  '16772': -1.0,
#  '12834': -1.09,
#  '8226': -1.0,
#  '11663': -1.0,
#  '14856': -1.0,
#  '6497': -1.09,
#  '10734': -1.0,
#  '4472': -1.0,
#  '15887': -1.0,
#  '9689': -1.0,
#  '3713': -1.0,
#  '16208': -1.0,
#  '8357': -1.09,
#  '8301': -1.0,
#  '9681': -0.9946608108108109,
#  '6931': -1.0,
#  '17355': -1.09,
#  '3553': -1.0,
#  '2192': -1.0,
#  '6591': -1.0,
#  '8585': -1.0,
#  '2371': -1.0,
#  '8904': -1.0,
#  '13728': -1.0,
#  '818': -1.0,
#  '4315': -1.0,
#  '15496': -1.09,
#  '14691': -1.0,
#  '14312': -1.0,
#  '6206': -1.0,
#  '9051': -1.0,
#  '9728': -1.0045076825798294,
#  '3239': -1.09,
#  '12195': -1.0,
#  '3490': -1.0,
#  '16201': -1.0,
#  '13359': -1.0,
#  '3920': -1.0000903010033446,
#  '15316': -1.0,
#  '5561': -1.0,
#  '11209': -1.0,
#  '7019': -0.9974307958477509,
#  '14968': -1.0,
#  '13923': -1.0,
#  '12672': -1.0,
#  '5069': -1.0,
#  '6386': -1.0,
#  '6408': -1.09,
#  '13302': -1.0,
#  '7928': -1.0,
#  '2499': -1.0,
#  '3418': -1.0,
#  '6826': -1.0,
#  '4056': -1.0,
#  '7833': -0.9974307958477509,
#  '1160': -1.0,
#  '8840': -1.0,
#  '4545': -1.0,
#  '4515': -1.09,
#  '9741': -1.0,
#  '12931': -1.0,
#  '14657': -1.0,
#  '6166': -1.0,
#  '5571': -1.09,
#  '10125': -1.0981,
#  '16676': -1.0000903010033446,
#  '38': -1.0,
#  '14999': -1.09,
#  '10872': -1.0,
#  '3962': -1.0,
#  '15345': -1.0,
#  '16415': -1.0,
#  '17644': -1.0,
#  '2379': -1.0,
#  '5085': -1.09,
#  '13384': -1.0,
#  '14296': -1.0,
#  '12914': -1.0,
#  '5667': -1.0,
#  '9235': -1.09,
#  '6908': -1.0,
#  '17672': -0.9986225609756098,
#  '12732': -1.0,
#  '17627': -1.0,
#  '12470': -1.0,
#  '1180': -1.0,
#  '11740': -1.09,
#  '16390': -1.09,
#  '6050': -1.0,
#  '2102': -1.0,
#  '10375': -1.0,
#  '3649': -1.0,
#  '11781': -1.0,
#  '3801': -1.0,
#  '13129': -1.0,
#  '8571': -0.996783439490446,
#  '15995': -1.0,
#  '4488': -1.0,
#  '7064': -1.0,
#  '2779': -1.0,
#  '4256': -1.0,
#  '12586': -1.0,
#  '12497': -1.0,
#  '15597': -1.09,
#  '464': -1.09,
#  '14869': -1.09,
#  '12911': -1.0,
#  '257': -1.0,
#  '5601': -1.0,
#  '16992': -1.0,
#  '88': -1.0,
#  '1890': -1.0,
#  '5877': -1.0,
#  '5765': -1.0,
#  '14550': -1.0,
#  '12870': -1.0,
#  '1865': -1.09,
#  '6196': -1.0,
#  '8384': -1.0,
#  '15764': -0.9978174706649283,
#  '14961': -1.0,
#  '5708': -1.0,
#  '16499': -1.09,
#  '14219': -0.9970684540787222,
#  '10682': -1.0,
#  '4067': -1.0,
#  '13195': -1.0,
#  '11952': -0.9974307958477509,
#  '7773': -1.0,
#  '9144': -1.0,
#  '11775': -1.0,
#  '2342': -1.0,
#  '16016': -1.09,
#  '1476': -1.0,
#  '10835': -1.0,
#  '16872': -1.0,
#  '16755': -1.0981,
#  '8981': -1.0,
#  '11092': -1.0,
#  '5924': -1.0,
#  '12161': -1.0,
#  '15445': -1.0,
#  '4912': -0.9974307958477509,
#  '15209': -1.0,
#  '3638': -1.0,
#  '238': -1.0,
#  '5809': -1.0,
#  '10139': -1.0,
#  '12435': -1.0,
#  '16438': -1.09,
#  '11929': -1.0,
#  '7922': -1.0,
#  '15975': -1.0,
#  '15997': -0.9968404255319149,
#  '3047': -1.0,
#  '7032': -1.0,
#  '3875': -1.0981,
#  '6013': -1.0,
#  '14928': -1.0,
#  '2920': -1.0,
#  '4805': -1.0,
#  '15943': -1.0000903010033446,
#  '15945': -1.09,
#  '10073': -1.0,
#  '16377': -1.0,
#  '6475': -1.0,
#  '16596': -1.0,
#  '15205': -1.0,
#  '11435': -1.0,
#  '8987': -1.0,
#  '3433': -1.0,
#  '5628': -0.9952647727272729,
#  '16259': -1.0,
#  '7606': -1.0,
#  '9205': -1.09,
#  '17308': -1.0,
#  '10566': -1.0,
#  '9617': -1.0,
#  '4429': -1.0,
#  '4790': -1.0,
#  '8159': -1.09,
#  '3817': -1.0,
#  '6637': -1.0,
#  '11891': -1.0,
#  '7173': -1.0,
#  '7435': -1.0,
#  '8586': -1.0,
#  '731': -1.0,
#  '11110': -1.0,
#  '6874': -1.0,
#  '3610': -1.0,
#  '13471': -1.09,
#  '17112': -1.09,
#  '17491': -1.0,
#  '12605': -1.09,
#  '9903': -1.0,
#  '3758': -1.0,
#  '4586': -1.0,
#  '17412': -1.0,
#  '5033': -1.09,
#  '16890': -1.0,
#  '16538': -1.0,
#  '7509': -1.0,
#  '11840': -1.0981,
#  '14327': -1.0,
#  '9565': -1.0,
#  '11884': -0.996778947368421,
#  '6808': -1.0,
#  '14457': -1.09,
#  '8621': -1.0,
#  '9027': -1.0,
#  '13614': -1.0,
#  '6708': -1.0045076825798294,
#  '1367': -1.0,
#  '6345': -1.0,
#  '5345': -1.09,
#  '13524': -1.0,
#  '13675': -1.0,
#  '15282': -1.0,
#  '15844': -1.0,
#  '3071': -1.0,
#  '17560': -1.0,
#  '16931': -1.0,
#  '14155': -1.0,
#  '6630': -1.0,
#  '12096': -1.0,
#  '11134': -1.09,
#  '17324': -1.0,
#  '13691': -1.0,
#  '13102': -1.0,
#  '14889': -1.0,
#  '2735': -1.0045076825798294,
#  '13887': -1.0981,
#  '6219': -1.0,
#  '16524': -1.0,
#  '6760': -1.0,
#  '14909': -1.0,
#  '6205': -1.0,
#  '15450': -1.0,
#  '2800': -1.0,
#  '8644': -1.0,
#  '14454': -1.0,
#  '13636': -1.0,
#  '15545': -1.09,
#  '16954': -1.0,
#  '12034': -1.0,
#  '2812': -1.0,
#  '15702': -1.09,
#  '508': -1.0,
#  '7158': -1.09,
#  '15853': -1.09,
#  '4266': -1.0895738295454547,
#  '5462': -1.0,
#  '11912': -1.09,
#  '7815': -1.0,
#  '7483': -1.0,
#  '17638': -1.0,
#  '2866': -1.09,
#  '9395': -1.0,
#  '14147': -1.09,
#  '12275': -1.0,
#  '6804': -0.9974307958477509,
#  '5515': -1.0,
#  '17357': -1.0981,
#  '2860': -1.0,
#  '12966': -1.09,
#  '11980': -1.09,
#  '330': -1.0,
#  '7642': -1.0,
#  '7127': -1.0,
#  '7383': -1.0,
#  '148': -1.0,
#  '8046': -1.09,
#  '14621': -1.0,
#  '4778': -1.09,
#  '11075': -1.0,
#  '14960': -1.0,
#  '13217': -1.0,
#  '9438': -1.09,
#  '7513': -1.0,
#  '9378': -1.0,
#  '4697': -1.0,
#  '12843': -1.0,
#  '6988': -0.9934383720930233,
#  '15816': -0.9973150232919255,
#  '13582': -0.9967537313432836,
#  '3312': -1.0,
#  '2122': -1.09,
#  '17536': -1.0981,
#  '833': -1.0,
#  '13439': -1.0,
#  '15799': -1.0,
#  '2594': -1.0981,
#  '10436': -1.09,
#  '5642': -1.0,
#  '16792': -1.0}
